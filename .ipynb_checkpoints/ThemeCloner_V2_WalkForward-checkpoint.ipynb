# %% [markdown]
# # ThemeCloner V2 -- Walk-Forward RP-PCA
#
# **Forked from ThemeCloner V1** (see `ThemeCloner/` repo for the submitted paper and its full single-snapshot diagnostic suite -- that pipeline is untouched).
#
# This notebook implements the two changes scoped as ThemeCloner 2.0:
# 1. **Residualization keeps each stock's alpha** (`keep_alpha=True`) instead of forcing residuals to be mean-zero, so RP-PCA's premium-reward penalty has real cross-sectional mean-return information to exploit -- this is the actual mathematical difference between RP-PCA and plain PCA, which V1 confirmed collapses to PCA under mean-zero residuals (V1 paper, Section 3.3).
# 2. **Walk-forward, point-in-time estimation** (`src/rppca_walkforward.py`, `src/backtest_v2.py`): RP-PCA is refit at every rebalance date using only trailing data, theme fingerprints and candidate scores are built the same way, and baskets are held for a genuine forward period with realized (not in-sample) returns recorded. This closes the temporal look-ahead gap flagged in the V1 write-up: V1's "out-of-sample" validation was cross-sectional only (target-universe stocks held out) but the factor model itself was fit once on the full sample.
#
# **Reused unchanged from V1:** `src/data_pull.py`, `src/rppca.py` (the core RP-PCA solver), `src/theme_dna.py` (`label_theme_factors`), `src/scoring.py` (`rank_candidates`), `src/theme_diagnostics.py`, `src/momentum_test.py`. Only `src/residualize.py` gained a new `keep_alpha` parameter (default `False`, so it is fully backward compatible with V1). Two new files, `src/rppca_walkforward.py` and `src/backtest_v2.py`, hold the walk-forward loop itself; `src/projection.py` gained new V2 scoring/null-test functions alongside its original V1 ones.

# %%
# -------------------- 0. Setup --------------------

import sys, os

# make sure we run from the ThemeCloner root regardless of where Jupyter launched
ROOT = os.path.abspath(os.path.join(os.getcwd()))
if not os.path.exists(os.path.join(ROOT, 'config', 'etfs.csv')):
    ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
os.chdir(ROOT)
sys.path.insert(0, ROOT)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12, 5)
matplotlib.rcParams['axes.spines.top'] = False
matplotlib.rcParams['axes.spines.right'] = False

print(f'root: {ROOT}')
print(f'config exists: {os.path.exists("config/etfs.csv")}')
print('setup done')
# Out:
# root: C:\Users\aamin\ThemeCloner2
# config exists: True
# setup done

# %% [markdown]
# ## Step 1 — Pull Data

# %%
# -------------------- 1a. Load ETF config --------------------

from src.data_pull import (load_etf_config, pull_etf_returns,
                            pull_covariance_universe, pull_target_universe)

# parameters -- tune these for the run
START_DATE  = '2018-01-01'
K           = 15     # factors for covariance universe RP-PCA (more themes need more K)
GAMMA       = 10.0   # Lettau-Pelger default
TOP_N       = 30     # candidates per theme
MIN_SCORE   = 0.40   # minimum cosine similarity to be a candidate
TOP_FACTORS = 3      # how many factors per ETF to use for theme fingerprint
RESIDUALIZE_MOMENTUM = False  # False = strip FF5 only (keep momentum)
INCLUDE_COMMODITY    = False  # EXPERIMENT 1: True = also strip commodity beta
                              # (DBC/DBE/DBB/GLD/DBA) to test if it rescues
                              # Clean Energy / Agribusiness from commodity contamination

etf_config = load_etf_config('config/etfs.csv')
etf_config


# split discovery themes from calibration controls (sector/subsector)
from src.data_pull import split_themes_controls
themes_config, controls_config = split_themes_controls(etf_config)
print(f'\n{len(themes_config["theme"].unique())} discovery themes, '
      f'{len(controls_config["theme"].unique())} calibration controls')
# Out:
# loaded 44 ETFs: 31 theme-ETFs, 13 control-ETFs (sector/subsector calibration anchors)
#   AI Infrastructure: IGPT (IGPT), QTUM (QTUM), SOXX (SOXX)
#   Agribusiness: MOO (MOO), VEGI (VEGI), PBJ (PBJ)
#   Clean Energy: ICLN (ICLN), QCLN (QCLN), PBW (PBW)
#   Critical Minerals: URA (URA), LIT (LIT), COPX (COPX)
#   Cybersecurity: CIBR (CIBR), HACK (HACK), BUG (BUG)
#   Defense: ITA (ITA), PPA (PPA), XAR (XAR)
#   Factor1: IUSG (IUSG)
#   Factor2: VLUE (VLUE)
#   Factor3: QUAL (QUAL)
#   Factor4: SPGP (SPGP)
#   Factor5: MTUM (MTUM)
#   Factor6: VUG (VUG)
#   Factor7: VTV (VTV)
#   Fintech: FINX (FINX), ARKF (ARKF), IPAY (IPAY)
#   Robotics & AI: BOTZ (BOTZ), ROBO (ROBO), IRBO (IRBO)
#   SECTOR: US Energy: XLE (XLE)
#   SECTOR: US Financials: XLF (XLF)
#   SECTOR: US Technology: XLK (XLK)
#   SUBSECTOR: US Banks: KRE (KRE)
#   SUBSECTOR: US Biotech: XBI (XBI)
#   SUBSECTOR: US Software: IGV (IGV)
#   Timber & Forestry: WOOD (WOOD), CUT (CUT)
#   US Infrastructure: PAVE (PAVE), IFRA (IFRA)
#   Water: PHO (PHO), FIW (FIW), CGW (CGW)
#
# 11 discovery themes, 13 calibration controls

# %%
# -------------------- 1b. Pull ETF returns --------------------
# these serve two roles: theme definition (labeling factors) and OOS validation

etf_returns = pull_etf_returns(etf_config, start=START_DATE)
etf_returns.tail(3)
# Out:
# pulling ETF panel: 44 tickers in 1 batch(es)
#   batch 1/1 (44 tickers)...
#   dropped 1 tickers below 85% coverage
#   ETF panel: 444 weeks x 43 stocks
#   date range: 2018-01-12 to 2026-07-10
#   ETFs kept: ['ARKF', 'BOTZ', 'CGW', 'CIBR', 'COPX', 'CUT', 'FINX', 'FIW', 'HACK', 'ICLN', 'IFRA', 'IGPT', 'IGV', 'IPAY', 'IRBO', 'ITA', 'IUSG', 'KRE', 'LIT', 'MOO', 'MTUM', 'PAVE', 'PBJ', 'PBW', 'PHO', 'PPA', 'QCLN', 'QTUM', 'QUAL', 'ROBO', 'SOXX', 'SPGP', 'URA', 'VEGI', 'VLUE', 'VTV', 'VUG', 'WOOD', 'XAR', 'XBI', 'XLE', 'XLF', 'XLK']
#                 ARKF      BOTZ       CGW      CIBR      COPX       CUT  \
# Date
# 2026-06-26 -0.020952 -0.063479  0.032378  0.010512 -0.115184  0.008190
# 2026-07-03  0.044163  0.038107  0.003196  0.060349  0.009543  0.002125
# 2026-07-10  0.019578 -0.011296 -0.002434  0.014018  0.000848 -0.010315
#
#                 FINX       FIW     HACK      ICLN  ...      VEGI      VLUE  \
# Date                                               ...
# 2026-06-26 -0.002807  0.033043  0.02723 -0.078859  ...  0.014283  0.000850
# 2026-07-03  0.028280 -0.003937  0.08097  0.008680  ...  0.010693 -0.036233
# 2026-07-10  0.002734 -0.008014  0.01779 -0.022623  ... -0.004900  0.013025
#
#                  VTV       VUG      WOOD       XAR       XBI       XLE  \
# Date
# 2026-06-26  0.013611 -0.048625 -0.007160 -0.036320  0.100083  0.008487
# 2026-07-03  0.003565  0.032571 -0.000899  0.047975  0.032171 -0.011582
# 2026-07-10 -0.001530  0.020674  0.014902 -0.055777 -0.013269  0.024042
#
#                  XLF       XLK
# Date
# 2026-06-26  0.003497 -0.054278
# 2026-07-03  0.037554 -0.002875
# 2026-07-10 -0.000989  0.028280
#
# [3 rows x 43 columns]

# %%
# -------------------- 1c. Pull covariance universe (ACWI proxy) --------------------
# this is what RP-PCA runs on -- needs to be broad enough to capture all themes
# SP500 + SP400 + SP600 + STOXX600 + Nikkei225
# first run: ~10-15 min to pull. subsequent runs use cache.

cov_returns = pull_covariance_universe(start=START_DATE, use_cache=True, us_only=True)
print(f'covariance universe: {cov_returns.shape[1]} stocks x {cov_returns.shape[0]} weeks')
# Out:
# loaded covariance universe from cache (us_only): 1003 tickers across ['us_sp500', 'us_mid_small']
#
# pulling covariance universe: 1003 unique tickers
#
# pulling covariance universe: 1003 tickers in 3 batch(es)
#   batch 1/3 (400 tickers)...
# $RVTY: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $ADM: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CEG: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $MU: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $EIX: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $SATS: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $AIG: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $AON: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $RMD: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CRL: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $HUBB: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $ELV: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CAT: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $DD: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $GLW: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $LMT: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $PFG: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $IP: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $BLK: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $EXPE: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $MRNA: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $HSIC: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $ETN: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CMCSA: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $L: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $MRK: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $GEHC: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $MCD: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $RL: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $IBKR: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $APTV: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $IEX: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $APA: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $EBAY: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $IDXX: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CPT: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $NTRS: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $NWSA: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $NCLH: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $MSFT: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $DHI: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $ITW: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $NUE: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $KEY: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $BRO: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $AXON: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $AVY: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $LNT: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $DAL: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $NFLX: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $DVA: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $CB: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
# $ABNB: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
#
# 53 Failed downloads:
# ['RVTY', 'ADM', 'CEG', 'MU', 'EIX', 'SATS', 'AIG', 'AON', 'RMD', 'CRL', 'HUBB', 'ELV', 'CAT', 'DD', 'GLW', 'LMT', 'PFG', 'IP', 'BLK', 'MRNA', 'EXPE', 'HSIC', 'ETN', 'CMCSA', 'L', 'MRK', 'GEHC', 'MCD', 'RL', 'IBKR', 'APTV', 'IEX', 'APA', 'EBAY', 'IDXX', 'CPT', 'NTRS', 'NWSA', 'NCLH', 'MSFT', 'DHI', 'ITW', 'NUE', 'KEY', 'BRO', 'AXON', 'AVY', 'LNT', 'DAL', 'NFLX', 'DVA', 'CB', 'ABNB']: possibly delisted; no price data found  (1d 2018-01-01 -> 2026-07-10)
#   batch 2/3 (400 tickers)...
#   batch 3/3 (203 tickers)...
#   dropped 300 tickers below 85% coverage
#   covariance universe: 444 weeks x 703 stocks
#   date range: 2018-01-12 to 2026-07-10
# covariance universe: 703 stocks x 444 weeks

# %%
# -------------------- 1d. Pull target universe (Russell 2000 proxy) --------------------
# small caps we score for undiscovered thematic exposure
# first run: ~20-30 min. subsequent runs use cache.

from src.data_pull import _cached_returns, pull_target_universe

#tgt_returns = _cached_returns('target_universe_returns', pull_target_universe, refresh=True, start=START_DATE, use_cache=False)
tgt_returns = _cached_returns('target_universe_returns', pull_target_universe, refresh=False, start=START_DATE)

print(f'target universe: {tgt_returns.shape[1]} stocks x {tgt_returns.shape[0]} weeks')
# Out:
#   loaded target_universe_returns from cache: 444 weeks x 811 cols
# target universe: 811 stocks x 444 weeks

# %% [markdown]
# ## Step 1.5 (V2) -- Residualize, keeping alpha for the covariance universe

# %%
# -------------------- 1.5 (V2). Residualize -- keep_alpha=True for the covariance universe --------------------
# THIS IS V2 CHANGE #1. Compare to V1's equivalent cell: the only difference
# is keep_alpha=True on cov_returns. ETFs and target universe stay V1-style
# (keep_alpha=False / default) -- see src/projection.py's V2 docstring for
# why that's fine: the V2 scoring metric demeans both series anyway, so it
# doesn't need alpha preserved on the ETF/target side, only on the
# covariance universe side where RP-PCA's mu term actually lives.

from src.residualize import get_combined_factors, residualize_returns, standardize_residuals

ff_factors = get_combined_factors(start=START_DATE, include_commodity=INCLUDE_COMMODITY)

print("\n" + "="*70)
print("RESIDUALIZING COVARIANCE UNIVERSE (keep_alpha=True -- V2 change #1)")
print("="*70)
cov_residuals_keepalpha = residualize_returns(cov_returns, ff_factors, keep_alpha=True)
cov_residuals_keepalpha = standardize_residuals(cov_residuals_keepalpha)

print("\n" + "="*70)
print("RESIDUALIZING ETF RETURNS (V1-style, keep_alpha=False)")
print("="*70)
etf_residuals = residualize_returns(etf_returns, ff_factors, keep_alpha=False)

print("\n" + "="*70)
print("RESIDUALIZING TARGET UNIVERSE (V1-style, keep_alpha=False)")
print("="*70)
tgt_residuals = residualize_returns(tgt_returns, ff_factors, keep_alpha=False)
# Out:
# pulling FF5 + momentum from Kenneth French library (weekly)...
#   momentum fetch failed via pandas_datareader (Unknown datetime string format, unable to parse: Missing data are indicated by -99.99 or -999., at position 0)
#   falling back to direct download from Ken French's data library...
#   first 20 raw lines (for diagnosis):
#     'This file was created by using the 202605 CRSP database.  It,,'
#     'contains a momentum factor, constructed from six value-weight portfolios formed,'
#     'using independent sorts on size and prior return of NYSE, AMEX, and NASDAQ stocks.'
#     'MOM is the average of the returns on two (big and small) high prior return portfolios,,'
#     'minus the average of the returns on two low prior return portfolios.  The portfolios,,'
#     'are constructed daily.  Big means a firm is above the median market cap on the NYSE,,'
#     'at the end of the previous day; small firms are below the median NYSE market cap.,,'
#     'Prior return is measured from day - 250 to - 21.  Firms in the low prior return,,'
#     'portfolio are below the 30th NYSE percentile.  Those in the high portfolio are above,,'
#     'the 70th NYSE percentile.,,'
#     ',,'
#     'Missing data are indicated by -99.99 or -999.,,'
#     ',,'
#     ',Mom,'
#     '19261103,0.35,'
#     '19261104,-0.61,'
#     '19261105,1.15,'
#     '19261106,-0.18,'
#     '19261108,-0.05,'
#     '19261109,0.19,'
#   momentum recovered via direct download: 2113 obs
#   factors: ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'RF', 'MOM']
#   date range: 2018-01-05 to 2026-05-29
#   observations: 439
#
# ======================================================================
# RESIDUALIZING COVARIANCE UNIVERSE (keep_alpha=True -- V2 change #1)
# ======================================================================
#
# residualizing 703 stocks against 6 factors (keep_alpha=True, V2)
#   factor cols: ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'MOM']
#   common dates: 438 weeks
#   excess returns computed (subtracted RF)
#   average R² across stocks: 0.367
#   (high R² = factor model explains a lot, low residual variance left)
#   mean |alpha| across stocks (annualised): 0.121
#   (this is the cross-sectional mean-return signal RP-PCA's penalty now sees)
#   standardized 703 stocks to unit vol (winsorized at 1%/99%)
#
# ======================================================================
# RESIDUALIZING ETF RETURNS (V1-style, keep_alpha=False)
# ======================================================================
#
# residualizing 43 stocks against 6 factors
#   factor cols: ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'MOM']
#   common dates: 438 weeks
#   excess returns computed (subtracted RF)
#   average R² across stocks: 0.769
#   (high R² = factor model explains a lot, low residual variance left)
#
# ======================================================================
# RESIDUALIZING TARGET UNIVERSE (V1-style, keep_alpha=False)
# ======================================================================
#
# residualizing 811 stocks against 6 factors
#   factor cols: ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'MOM']
#   common dates: 438 weeks
#   excess returns computed (subtracted RF)
#   average R² across stocks: 0.221
#   (high R² = factor model explains a lot, low residual variance left)

# %% [markdown]
# ## Step 2 (V2) -- Build the Rebalance Schedule
#
# Quarterly rebalances, each requiring at least 2 years of trailing history before it's included. This directly answers the "can I keep rotating in and out of these positions" question from the V1 conversation -- instead of asserting stability from one fit, we now observe it, or don't, across real rebalance dates.

# %%
# -------------------- 2 (V2). Rebalance schedule --------------------
from src.rppca_walkforward import make_rebalance_dates

REBALANCE_FREQ = 'Q'          # quarterly
MIN_WINDOW_WEEKS = 104          # 2 years minimum trailing history
WALKFORWARD_WINDOW = 'expanding'  # 'expanding' or 'rolling'
ROLLING_WINDOW_WEEKS = 208      # only used if WALKFORWARD_WINDOW == 'rolling'

rebalance_dates = make_rebalance_dates(cov_residuals_keepalpha.index,
                                        freq=REBALANCE_FREQ,
                                        min_window_weeks=MIN_WINDOW_WEEKS)
print(f"{len(rebalance_dates)} rebalance dates:")
for d in rebalance_dates:
    print(f"  {d.date()}")
# Out:
# 25 rebalance dates:
#   2020-03-27
#   2020-06-26
#   2020-09-25
#   2020-12-25
#   2021-03-26
#   2021-06-25
#   2021-09-24
#   2021-12-31
#   2022-03-25
#   2022-06-24
#   2022-09-30
#   2022-12-30
#   2023-03-31
#   2023-06-30
#   2023-09-29
#   2023-12-29
#   2024-03-29
#   2024-06-28
#   2024-09-27
#   2024-12-27
#   2025-03-28
#   2025-06-27
#   2025-09-26
#   2025-12-26
#   2026-03-27

# %% [markdown]
# ## Step 3 (V2) -- Factor Identity Drift
#
# Before running the full backtest: how stable is each factor's economic identity from one rebalance to the next? This is computed directly from walk-forward RP-PCA fits, not asserted from a single snapshot.

# %%
# -------------------- 3 (V2). Walk-forward RP-PCA fits + factor drift --------------------
from src.rppca_walkforward import rolling_rppca_fit, factor_drift_report

K = 15
GAMMA = 10.0

walkforward_fits = rolling_rppca_fit(
    cov_residuals_keepalpha, rebalance_dates,
    K=K, gamma=GAMMA, window=WALKFORWARD_WINDOW,
    rolling_window_weeks=ROLLING_WINDOW_WEEKS,
)

drift = factor_drift_report(walkforward_fits)
# Out:
# [1/25] fitting RP-PCA as of 2020-03-27 (expanding, 116 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.797
#   top eigenvalues:   [78.8 46.9 27.6 19.6 18.3 16.7 14.3 12.7 11.4 11.  10.5 10.1  9.3  8.7
#   8.5]
#
# [2/25] fitting RP-PCA as of 2020-06-26 (expanding, 129 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.386
#   top eigenvalues:   [74.1 40.8 27.9 22.6 21.6 17.  16.5 14.2 13.3 12.  11.3 10.3 10.1  9.9
#   9.6]
#
# [3/25] fitting RP-PCA as of 2020-09-25 (expanding, 142 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.721
#   top eigenvalues:   [69.3 40.5 26.6 22.3 20.6 16.9 15.5 14.1 12.7 11.9 10.9 10.4  9.6  9.4
#   9.3]
#
# [4/25] fitting RP-PCA as of 2020-12-25 (expanding, 155 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.230
#   top eigenvalues:   [64.3 36.4 25.6 22.  20.4 17.1 14.6 13.6 12.3 11.4 10.5 10.   9.4  9.1
#   8.9]
#
# [5/25] fitting RP-PCA as of 2021-03-26 (expanding, 168 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.189
#   top eigenvalues:   [62.3 33.5 24.6 21.4 19.9 16.6 14.4 13.6 11.9 11.3 10.1 10.   9.4  9.2
#   8.8]
#
# [6/25] fitting RP-PCA as of 2021-06-25 (expanding, 181 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.985
#   top eigenvalues:   [59.7 31.  23.5 21.3 18.9 15.8 13.9 13.  11.2 10.6  9.7  9.4  9.   8.8
#   8.4]
#
# [7/25] fitting RP-PCA as of 2021-09-24 (expanding, 194 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.173
#   top eigenvalues:   [56.6 32.  23.2 20.2 18.  15.1 13.3 12.4 10.6 10.2  9.2  8.9  8.5  8.4
#   8. ]
#
# [8/25] fitting RP-PCA as of 2021-12-31 (expanding, 208 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.058
#   top eigenvalues:   [54.1 33.3 22.9 19.7 16.8 14.7 12.8 12.  10.7 10.   9.   8.5  8.2  8.1
#   7.7]
#
# [9/25] fitting RP-PCA as of 2022-03-25 (expanding, 220 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.955
#   top eigenvalues:   [53.6 33.1 22.5 20.8 16.6 14.8 12.6 12.1 10.4  9.7  9.1  8.6  8.1  8.
#   7.6]
#
# [10/25] fitting RP-PCA as of 2022-06-24 (expanding, 233 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.817
#   top eigenvalues:   [53.3 32.2 22.7 20.5 16.7 15.3 12.5 11.9 10.4  9.7  9.1  8.5  8.3  8.2
#   7.8]
#
# [11/25] fitting RP-PCA as of 2022-09-30 (expanding, 247 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.793
#   top eigenvalues:   [52.1 32.9 22.2 20.3 16.6 15.3 12.6 11.4 10.3  9.4  8.7  8.5  8.2  8.
#   7.7]
#
# [12/25] fitting RP-PCA as of 2022-12-30 (expanding, 260 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.775
#   top eigenvalues:   [51.7 30.8 22.3 20.5 16.7 15.4 12.4 11.2 10.2  9.2  8.9  8.4  8.1  7.8
#   7.4]
#
# [13/25] fitting RP-PCA as of 2023-03-31 (expanding, 273 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.356
#   top eigenvalues:   [50.2 29.3 23.4 19.7 16.2 15.1 11.9 11.2 10.2  9.1  8.7  8.3  7.9  7.6
#   7.3]
#
# [14/25] fitting RP-PCA as of 2023-06-30 (expanding, 286 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.184
#   top eigenvalues:   [50.4 28.3 23.  19.4 16.  14.8 11.8 11.1 10.2  9.1  8.5  8.3  7.9  7.4
#   7.2]
#
# [15/25] fitting RP-PCA as of 2023-09-29 (expanding, 299 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.055
#   top eigenvalues:   [51.1 27.3 22.5 18.6 15.6 14.5 11.4 10.8  9.8  8.9  8.3  8.1  7.8  7.3
#   7.2]
#
# [16/25] fitting RP-PCA as of 2023-12-29 (expanding, 312 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.091
#   top eigenvalues:   [49.4 26.6 21.9 20.2 15.5 14.5 11.2 10.7  9.5  8.6  8.2  7.8  7.6  7.2
#   7. ]
#
# [17/25] fitting RP-PCA as of 2024-03-29 (expanding, 325 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      4.925
#   top eigenvalues:   [49.1 25.3 21.4 19.9 15.2 14.3 10.9 10.5  9.2  8.4  8.2  7.7  7.5  7.
#   6.8]
#
# [18/25] fitting RP-PCA as of 2024-06-28 (expanding, 338 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.180
#   top eigenvalues:   [48.9 25.1 21.3 19.2 15.5 14.2 10.7 10.3  9.1  8.2  8.   7.6  7.4  7.
#   6.7]
#
# [19/25] fitting RP-PCA as of 2024-09-27 (expanding, 351 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.390
#   top eigenvalues:   [49.1 25.4 21.8 19.2 15.4 13.9 10.6 10.3  8.8  8.1  7.9  7.5  7.2  6.9
#   6.7]
#
# [20/25] fitting RP-PCA as of 2024-12-27 (expanding, 364 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.412
#   top eigenvalues:   [50.  26.1 21.6 18.9 15.1 14.3 10.5 10.1  8.6  8.1  7.8  7.4  7.2  6.8
#   6.6]
#
# [21/25] fitting RP-PCA as of 2025-03-28 (expanding, 377 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.264
#   top eigenvalues:   [48.4 27.1 21.6 18.3 15.3 14.4 10.4  9.9  8.6  8.3  7.9  7.3  7.1  6.6
#   6.5]
#
# [22/25] fitting RP-PCA as of 2025-06-27 (expanding, 390 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.342
#   top eigenvalues:   [51.4 26.6 21.4 19.  15.  14.4 10.5 10.   8.5  8.3  7.9  7.4  7.   6.6
#   6.4]
#
# [23/25] fitting RP-PCA as of 2025-09-26 (expanding, 403 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.346
#   top eigenvalues:   [51.3 26.1 21.1 18.6 14.7 14.2 10.6 10.1  8.4  8.4  7.7  7.3  7.   6.5
#   6.3]
#
# [24/25] fitting RP-PCA as of 2025-12-26 (expanding, 416 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.517
#   top eigenvalues:   [51.8 26.1 20.5 18.5 14.7 14.1 10.7 10.1  8.5  8.3  7.5  7.2  7.1  6.4
#   6.4]
#
# [25/25] fitting RP-PCA as of 2026-03-27 (expanding, 429 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.469
#   top eigenvalues:   [51.7 27.8 20.7 17.9 16.2 14.1 11.8  9.9  8.6  8.2  7.5  7.2  7.   6.7
#   6.4]
#
# factor identity drift (cosine similarity to the SAME factor_k, prior period):
#             mean    min
# factor
# factor_1   0.583 -0.999
# factor_10  0.511 -0.991
# factor_11  0.266 -0.984
# factor_12  0.411 -0.976
# factor_13  0.428 -0.986
# factor_14  0.364 -0.972
# factor_15  0.179 -0.935
# factor_2   0.319 -0.987
# factor_3   0.659 -0.997
# factor_4   0.582 -0.995
# factor_5   0.588 -0.978
# factor_6   0.579 -0.990
# factor_7   0.484 -0.983
# factor_8   0.164 -0.987
# factor_9   0.476 -0.997
#   near 1.0 = stable identity, safe to hold across rebalances
#   near 0 or negative = factor has rotated, re-underwrite before re-sizing

# %% [markdown]
# ## Step 4 (V2) -- Full Walk-Forward Backtest
#
# This is the centerpiece. At every rebalance date: fit RP-PCA on trailing data only, build fingerprints on trailing ETF data only, score candidates on trailing target-universe data only, then hold the resulting basket for one forward period and record its REALIZED return -- data none of the prior steps ever saw.

# %%
# -------------------- 4 (V2). Run the walk-forward backtest --------------------
from src.backtest_v2 import run_walkforward_backtest, summarize_backtest

TOP_N = 30
MIN_SCORE_V2 = -1.0   # V2 scores are correlations, can be legitimately negative;
                       # start permissive and tighten once score distributions are inspected
TOP_FACTORS = 3

wf_backtest = run_walkforward_backtest(
    cov_returns_resid_keepalpha=cov_residuals_keepalpha,
    etf_returns_resid=etf_residuals,
    target_returns_resid=tgt_residuals,
    target_returns_raw=tgt_returns,   # REAL returns for computing realized forward P&L
    etf_config=themes_config,
    rebalance_dates=rebalance_dates,
    K=K, gamma=GAMMA, window=WALKFORWARD_WINDOW,
    rolling_window_weeks=ROLLING_WINDOW_WEEKS,
    top_n=TOP_N, min_score=MIN_SCORE_V2, top_factors=TOP_FACTORS,
)

backtest_summary = summarize_backtest(wf_backtest['forward_returns'])
# Out:
# ======================================================================
# rebalance 1/25: 2020-03-27
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2020-03-27 (expanding, 116 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.797
#   top eigenvalues:   [78.8 46.9 27.6 19.6 18.3 16.7 14.3 12.7 11.4 11.  10.5 10.1  9.3  8.7
#   8.5]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.688  f6:-0.002, f8:+0.002, f3:+0.002
#   BOTZ                   0.522  f5:-0.001, f6:+0.001, f3:+0.001
#   CGW                    0.732  f5:-0.001, f6:+0.001, f1:-0.001
#   CIBR                   0.546  f4:-0.002, f9:+0.002, f13:+0.001
#   COPX                   0.456  f8:-0.002, f2:+0.002, f1:+0.002
#   CUT                    0.309  f12:-0.001, f6:+0.001, f8:-0.001
#   FINX                   0.570  f3:+0.001, f5:+0.001, f1:-0.001
#   FIW                    0.711  f10:-0.001, f6:+0.001, f1:-0.001
#   HACK                   0.455  f4:-0.002, f9:+0.001, f13:+0.001
#   ICLN                   0.418  f2:+0.001, f3:-0.001, f5:-0.001
#   IFRA                   0.641  f1:-0.001, f4:-0.001, f5:-0.001
#   IGPT                   0.375  f4:-0.001, f15:-0.001, f5:+0.001
#   IGV                    0.497  f7:-0.001, f4:-0.001, f6:-0.001
#   IPAY                   0.670  f5:+0.001, f1:-0.001, f3:+0.001
#   IRBO                   0.458  f12:+0.001, f4:-0.001, f6:-0.001
#   ITA                    0.736  f6:+0.002, f4:-0.002, f10:-0.001
#   IUSG                   0.524  f6:-0.000, f2:+0.000, f5:+0.000
#   KRE                    0.643  f2:-0.001, f8:+0.001, f4:+0.001
#   LIT                    0.308  f2:+0.001, f10:-0.001, f9:-0.001
#   MOO                    0.348  f6:+0.001, f12:-0.001, f8:-0.001
#   MTUM                   0.216  f9:-0.000, f12:+0.000, f13:+0.000
#   PAVE                   0.664  f6:+0.001, f3:+0.001, f9:-0.001
#   PBJ                    0.708  f3:-0.002, f10:+0.001, f6:+0.001
#   PBW                    0.255  f5:-0.001, f12:+0.001, f9:-0.001
#   PHO                    0.784  f7:-0.001, f10:-0.001, f1:-0.001
#   PPA                    0.720  f6:+0.002, f4:-0.001, f10:-0.001
#   QCLN                   0.447  f5:-0.002, f12:+0.001, f7:-0.001
#   QTUM                   0.457  f12:+0.001, f6:-0.001, f11:-0.001
#   QUAL                   0.343  f15:-0.000, f8:-0.000, f4:+0.000
#   ROBO                   0.630  f8:-0.001, f5:-0.001, f6:+0.001
#   SOXX                   0.754  f8:-0.003, f5:-0.002, f3:+0.002
#   SPGP                   0.444  f5:+0.001, f4:-0.001, f13:+0.000
#   URA                    0.184  f2:+0.002, f5:-0.001, f13:+0.001
#   VEGI                   0.291  f8:-0.001, f6:+0.001, f2:+0.001
#   VLUE                   0.295  f13:+0.000, f9:-0.000, f2:+0.000
#   VTV                    0.741  f6:+0.001, f3:-0.000, f1:-0.000
#   VUG                    0.663  f6:-0.001, f3:+0.000, f2:+0.000
#   WOOD                   0.205  f15:+0.001, f8:-0.001, f5:-0.001
#   XAR                    0.623  f4:-0.001, f6:+0.001, f10:-0.001
#   XBI                    0.525  f6:+0.002, f7:+0.002, f5:+0.001
#   XLE                    0.863  f4:-0.002, f2:+0.002, f5:+0.002
#   XLF                    0.730  f8:+0.001, f15:+0.001, f6:+0.001
#   XLK                    0.645  f6:-0.001, f3:+0.001, f12:-0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.537, purity=0.590
#   AI Infrastructure: 3 ETFs, avg R²=0.529, purity=0.478
#   Clean Energy: 3 ETFs, avg R²=0.373, purity=0.825
#   Cybersecurity: 2 ETFs, avg R²=0.500, purity=1.000
#   Defense: 3 ETFs, avg R²=0.693, purity=0.998
#   Fintech: 3 ETFs, avg R²=0.643, purity=0.812
#   US Infrastructure: 2 ETFs, avg R²=0.653, purity=0.707
#   Agribusiness: 3 ETFs, avg R²=0.449, purity=0.770
#   Critical Minerals: 3 ETFs, avg R²=0.316, purity=0.776
#   Water: 3 ETFs, avg R²=0.742, purity=0.826
#   Timber & Forestry: 2 ETFs, avg R²=0.257, purity=0.803
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.624, 0.803]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 2/25: 2020-06-26
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2020-06-26 (expanding, 129 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.386
#   top eigenvalues:   [74.1 40.8 27.9 22.6 21.6 17.  16.5 14.2 13.3 12.  11.3 10.3 10.1  9.9
#   9.6]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.595  f3:-0.003, f15:-0.002, f14:+0.001
#   BOTZ                   0.486  f6:-0.002, f3:-0.001, f7:-0.001
#   CGW                    0.637  f4:-0.001, f6:-0.001, f1:+0.001
#   CIBR                   0.499  f9:+0.002, f6:-0.001, f4:+0.001
#   COPX                   0.416  f2:+0.002, f11:+0.002, f10:-0.002
#   CUT                    0.208  f6:-0.001, f4:-0.001, f12:-0.001
#   FINX                   0.509  f3:-0.002, f1:+0.001, f15:-0.001
#   FIW                    0.704  f4:-0.001, f6:-0.001, f7:+0.001
#   HACK                   0.422  f9:+0.002, f6:-0.001, f4:+0.001
#   ICLN                   0.401  f6:-0.002, f9:-0.001, f3:+0.001
#   IFRA                   0.593  f6:-0.001, f1:+0.001, f12:-0.001
#   IGPT                   0.369  f4:+0.001, f7:+0.001, f2:-0.001
#   IGV                    0.499  f4:+0.001, f3:-0.001, f8:-0.001
#   IPAY                   0.682  f3:-0.001, f1:+0.001, f6:+0.001
#   IRBO                   0.383  f3:-0.001, f13:+0.001, f6:-0.001
#   ITA                    0.714  f8:-0.002, f5:-0.002, f6:-0.002
#   IUSG                   0.622  f7:+0.000, f10:+0.000, f3:-0.000
#   KRE                    0.661  f4:-0.001, f15:-0.001, f12:+0.001
#   LIT                    0.312  f2:+0.002, f12:-0.001, f6:-0.001
#   MOO                    0.312  f5:-0.001, f6:-0.001, f3:+0.001
#   MTUM                   0.293  f11:-0.000, f4:+0.000, f3:-0.000
#   PAVE                   0.766  f6:-0.001, f5:-0.001, f4:-0.001
#   PBJ                    0.712  f3:+0.002, f12:+0.001, f15:-0.001
#   PBW                    0.219  f6:-0.001, f9:-0.001, f15:-0.001
#   PHO                    0.728  f4:-0.001, f12:-0.001, f6:-0.001
#   PPA                    0.711  f8:-0.002, f6:-0.001, f5:-0.001
#   QCLN                   0.388  f6:-0.002, f8:+0.001, f2:+0.001
#   QTUM                   0.367  f13:+0.001, f3:-0.001, f8:+0.001
#   QUAL                   0.327  f4:-0.000, f5:-0.000, f11:+0.000
#   ROBO                   0.567  f6:-0.002, f3:-0.001, f14:-0.001
#   SOXX                   0.730  f8:+0.002, f3:-0.002, f6:-0.002
#   SPGP                   0.351  f5:-0.001, f9:+0.001, f12:-0.000
#   URA                    0.242  f8:+0.002, f6:-0.002, f2:+0.001
#   VEGI                   0.390  f6:-0.001, f8:+0.001, f5:-0.001
#   VLUE                   0.237  f11:-0.000, f2:+0.000, f14:+0.000
#   VTV                    0.785  f3:+0.001, f4:-0.000, f5:-0.000
#   VUG                    0.758  f3:-0.000, f7:+0.000, f14:-0.000
#   WOOD                   0.166  f6:-0.001, f8:+0.001, f15:-0.001
#   XAR                    0.627  f8:-0.002, f6:-0.002, f7:+0.001
#   XBI                    0.536  f3:+0.002, f6:+0.001, f15:+0.001
#   XLE                    0.883  f5:-0.004, f4:+0.003, f3:+0.002
#   XLF                    0.681  f8:-0.001, f4:-0.001, f9:-0.000
#   XLK                    0.667  f3:-0.001, f8:+0.001, f10:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.479, purity=0.910
#   AI Infrastructure: 3 ETFs, avg R²=0.489, purity=0.677
#   Clean Energy: 3 ETFs, avg R²=0.336, purity=0.884
#   Cybersecurity: 2 ETFs, avg R²=0.461, purity=0.999
#   Defense: 3 ETFs, avg R²=0.684, purity=0.942
#   Fintech: 3 ETFs, avg R²=0.595, purity=0.876
#   US Infrastructure: 2 ETFs, avg R²=0.680, purity=0.849
#   Agribusiness: 3 ETFs, avg R²=0.471, purity=0.743
#   Critical Minerals: 3 ETFs, avg R²=0.323, purity=0.807
#   Water: 3 ETFs, avg R²=0.689, purity=0.930
#   Timber & Forestry: 2 ETFs, avg R²=0.187, purity=0.886
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.506, 0.675]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 3/25: 2020-09-25
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2020-09-25 (expanding, 142 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.721
#   top eigenvalues:   [69.3 40.5 26.6 22.3 20.6 16.9 15.5 14.1 12.7 11.9 10.9 10.4  9.6  9.4
#   9.3]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.567  f3:-0.003, f15:-0.002, f10:+0.001
#   BOTZ                   0.485  f6:-0.002, f3:-0.001, f15:+0.001
#   CGW                    0.645  f6:-0.001, f1:+0.001, f4:-0.001
#   CIBR                   0.501  f9:-0.002, f11:+0.002, f15:+0.001
#   COPX                   0.340  f2:+0.002, f6:-0.001, f10:-0.001
#   CUT                    0.238  f6:-0.001, f14:-0.001, f4:-0.001
#   FINX                   0.482  f3:-0.001, f2:-0.001, f6:+0.001
#   FIW                    0.728  f7:+0.001, f3:+0.001, f4:-0.001
#   HACK                   0.402  f9:-0.002, f11:+0.001, f15:+0.001
#   ICLN                   0.351  f6:-0.001, f7:+0.001, f9:+0.001
#   IFRA                   0.579  f1:+0.001, f7:+0.001, f8:+0.001
#   IGPT                   0.381  f11:+0.001, f15:+0.001, f9:-0.001
#   IGV                    0.548  f11:+0.001, f3:-0.001, f4:+0.001
#   IPAY                   0.647  f6:+0.001, f1:+0.001, f3:-0.001
#   IRBO                   0.369  f3:-0.001, f15:+0.001, f13:+0.001
#   ITA                    0.740  f7:+0.002, f4:-0.002, f9:-0.001
#   IUSG                   0.506  f6:+0.000, f3:-0.000, f7:+0.000
#   KRE                    0.651  f11:+0.001, f5:+0.001, f15:-0.001
#   LIT                    0.183  f6:-0.001, f11:-0.001, f9:+0.001
#   MOO                    0.332  f4:-0.001, f6:-0.001, f3:+0.001
#   MTUM                   0.239  f12:+0.000, f5:-0.000, f3:-0.000
#   PAVE                   0.789  f4:-0.002, f7:+0.001, f12:-0.001
#   PBJ                    0.683  f3:+0.002, f11:+0.001, f6:-0.001
#   PBW                    0.181  f7:+0.001, f6:-0.001, f8:+0.001
#   PHO                    0.760  f4:-0.001, f5:+0.001, f7:+0.001
#   PPA                    0.727  f7:+0.002, f9:-0.001, f4:-0.001
#   QCLN                   0.305  f6:-0.001, f8:+0.001, f7:+0.001
#   QTUM                   0.332  f3:-0.001, f8:+0.001, f13:+0.001
#   QUAL                   0.377  f4:-0.000, f11:+0.000, f6:+0.000
#   ROBO                   0.590  f6:-0.001, f15:+0.001, f10:-0.001
#   SOXX                   0.717  f8:+0.002, f3:-0.002, f10:-0.001
#   SPGP                   0.323  f5:-0.001, f9:-0.001, f10:-0.000
#   URA                    0.203  f8:+0.002, f2:+0.001, f6:-0.001
#   VEGI                   0.397  f8:+0.001, f4:-0.001, f6:-0.001
#   VLUE                   0.248  f2:+0.001, f4:-0.000, f11:-0.000
#   VTV                    0.781  f3:+0.001, f4:-0.001, f2:+0.000
#   VUG                    0.683  f3:-0.001, f6:+0.000, f4:+0.000
#   WOOD                   0.166  f6:-0.001, f8:+0.001, f4:-0.001
#   XAR                    0.646  f7:+0.002, f8:-0.001, f9:-0.001
#   XBI                    0.471  f3:+0.002, f7:-0.002, f11:-0.001
#   XLE                    0.890  f5:-0.004, f3:+0.002, f2:+0.002
#   XLF                    0.694  f8:-0.001, f5:+0.001, f4:-0.001
#   XLK                    0.656  f3:-0.001, f6:+0.001, f8:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.482, purity=0.820
#   AI Infrastructure: 3 ETFs, avg R²=0.477, purity=0.701
#   Clean Energy: 3 ETFs, avg R²=0.279, purity=0.940
#   Cybersecurity: 2 ETFs, avg R²=0.451, purity=0.999
#   Defense: 3 ETFs, avg R²=0.704, purity=0.941
#   Fintech: 3 ETFs, avg R²=0.565, purity=0.831
#   US Infrastructure: 2 ETFs, avg R²=0.684, purity=0.807
#   Agribusiness: 3 ETFs, avg R²=0.471, purity=0.803
#   Critical Minerals: 3 ETFs, avg R²=0.242, purity=0.789
#   Water: 3 ETFs, avg R²=0.711, purity=0.793
#   Timber & Forestry: 2 ETFs, avg R²=0.202, purity=0.928
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.492, 0.577]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 4/25: 2020-12-25
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2020-12-25 (expanding, 155 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.230
#   top eigenvalues:   [64.3 36.4 25.6 22.  20.4 17.1 14.6 13.6 12.3 11.4 10.5 10.   9.4  9.1
#   8.9]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.563  f3:+0.003, f15:+0.002, f10:-0.001
#   BOTZ                   0.442  f6:+0.001, f4:+0.001, f9:+0.001
#   CGW                    0.646  f4:+0.001, f1:-0.001, f7:-0.001
#   CIBR                   0.426  f11:-0.002, f9:+0.001, f12:+0.001
#   COPX                   0.349  f15:+0.002, f2:-0.002, f6:+0.002
#   CUT                    0.259  f6:+0.001, f4:+0.001, f7:-0.001
#   FINX                   0.464  f3:+0.001, f2:+0.001, f5:+0.001
#   FIW                    0.695  f4:+0.001, f7:-0.001, f3:-0.001
#   HACK                   0.368  f9:+0.001, f11:-0.001, f12:+0.001
#   ICLN                   0.285  f6:+0.002, f2:+0.001, f7:-0.001
#   IFRA                   0.583  f7:-0.001, f8:-0.001, f1:-0.001
#   IGPT                   0.322  f11:-0.001, f4:-0.001, f13:-0.001
#   IGV                    0.450  f3:+0.001, f4:-0.001, f13:-0.001
#   IPAY                   0.593  f3:+0.001, f1:-0.001, f5:+0.001
#   IRBO                   0.355  f3:+0.001, f7:-0.001, f9:+0.001
#   ITA                    0.728  f5:+0.002, f7:-0.002, f8:+0.001
#   IUSG                   0.470  f6:-0.000, f3:+0.000, f13:-0.000
#   KRE                    0.684  f11:-0.001, f14:-0.001, f6:-0.001
#   LIT                    0.215  f6:+0.002, f13:+0.001, f8:-0.001
#   MOO                    0.359  f5:+0.001, f6:+0.001, f14:-0.001
#   MTUM                   0.258  f12:-0.000, f4:-0.000, f3:+0.000
#   PAVE                   0.760  f5:+0.001, f7:-0.001, f4:+0.001
#   PBJ                    0.672  f3:-0.002, f11:-0.001, f6:+0.001
#   PBW                    0.171  f2:+0.002, f6:+0.002, f7:-0.001
#   PHO                    0.728  f4:+0.001, f7:-0.001, f3:-0.001
#   PPA                    0.712  f5:+0.002, f7:-0.002, f8:+0.001
#   QCLN                   0.293  f12:-0.002, f6:+0.002, f8:-0.001
#   QTUM                   0.322  f3:+0.001, f9:+0.001, f8:-0.001
#   QUAL                   0.377  f5:+0.000, f6:-0.000, f4:+0.000
#   ROBO                   0.543  f7:-0.001, f4:+0.001, f6:+0.001
#   SOXX                   0.723  f3:+0.002, f8:-0.002, f10:+0.002
#   SPGP                   0.273  f5:+0.001, f10:+0.001, f9:+0.000
#   URA                    0.182  f8:-0.002, f7:-0.001, f2:-0.001
#   VEGI                   0.404  f13:+0.001, f6:+0.001, f5:+0.001
#   VLUE                   0.269  f2:-0.001, f13:+0.000, f4:+0.000
#   VTV                    0.790  f3:-0.001, f5:+0.000, f13:+0.000
#   VUG                    0.662  f3:+0.001, f13:-0.000, f6:-0.000
#   WOOD                   0.183  f6:+0.001, f4:+0.001, f11:-0.001
#   XAR                    0.619  f7:-0.002, f5:+0.002, f8:+0.001
#   XBI                    0.447  f3:-0.002, f13:+0.002, f7:+0.002
#   XLE                    0.909  f5:+0.003, f4:-0.003, f2:-0.002
#   XLF                    0.652  f8:+0.001, f10:-0.001, f13:+0.001
#   XLK                    0.621  f3:+0.001, f6:-0.001, f8:-0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.446, purity=0.750
#   AI Infrastructure: 3 ETFs, avg R²=0.456, purity=0.695
#   Clean Energy: 3 ETFs, avg R²=0.250, purity=0.846
#   Cybersecurity: 2 ETFs, avg R²=0.397, purity=0.999
#   Defense: 3 ETFs, avg R²=0.686, purity=0.998
#   Fintech: 3 ETFs, avg R²=0.540, purity=0.840
#   US Infrastructure: 2 ETFs, avg R²=0.672, purity=0.814
#   Agribusiness: 3 ETFs, avg R²=0.479, purity=0.734
#   Critical Minerals: 3 ETFs, avg R²=0.249, purity=0.737
#   Water: 3 ETFs, avg R²=0.690, purity=0.937
#   Timber & Forestry: 2 ETFs, avg R²=0.221, purity=0.939
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.517, 0.573]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 5/25: 2021-03-26
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2021-03-26 (expanding, 168 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.189
#   top eigenvalues:   [62.3 33.5 24.6 21.4 19.9 16.6 14.4 13.6 11.9 11.3 10.1 10.   9.4  9.2
#   8.8]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.587  f3:+0.003, f13:-0.002, f15:-0.002
#   BOTZ                   0.452  f4:+0.001, f6:+0.001, f3:+0.001
#   CGW                    0.610  f4:+0.001, f1:-0.001, f3:-0.001
#   CIBR                   0.403  f12:+0.002, f10:-0.001, f7:-0.001
#   COPX                   0.330  f6:+0.002, f3:+0.001, f13:-0.001
#   CUT                    0.296  f4:+0.001, f7:-0.001, f6:+0.001
#   FINX                   0.445  f3:+0.001, f12:+0.001, f5:+0.001
#   FIW                    0.649  f4:+0.001, f7:-0.001, f3:-0.001
#   HACK                   0.328  f12:+0.001, f9:-0.001, f10:-0.001
#   ICLN                   0.223  f6:+0.002, f2:+0.002, f11:-0.002
#   IFRA                   0.581  f8:-0.001, f1:-0.001, f6:+0.001
#   IGPT                   0.271  f12:+0.001, f4:-0.001, f3:+0.001
#   IGV                    0.484  f3:+0.001, f12:+0.001, f11:+0.001
#   IPAY                   0.572  f5:+0.001, f3:+0.001, f1:-0.001
#   IRBO                   0.376  f3:+0.001, f8:-0.001, f10:-0.001
#   ITA                    0.669  f5:+0.002, f9:-0.002, f7:-0.002
#   IUSG                   0.415  f3:+0.000, f15:-0.000, f6:-0.000
#   KRE                    0.680  f13:-0.002, f12:+0.002, f6:-0.001
#   LIT                    0.223  f6:+0.002, f8:-0.002, f11:-0.002
#   MOO                    0.357  f11:-0.001, f3:-0.001, f6:+0.001
#   MTUM                   0.241  f15:+0.000, f11:-0.000, f3:+0.000
#   PAVE                   0.748  f5:+0.001, f4:+0.001, f8:-0.001
#   PBJ                    0.647  f3:-0.002, f12:+0.001, f6:+0.001
#   PBW                    0.168  f6:+0.002, f2:+0.001, f10:+0.001
#   PHO                    0.672  f4:+0.001, f7:-0.001, f3:-0.001
#   PPA                    0.652  f5:+0.002, f7:-0.002, f9:-0.001
#   QCLN                   0.257  f11:-0.002, f8:-0.002, f6:+0.002
#   QTUM                   0.358  f8:-0.001, f3:+0.001, f10:-0.001
#   QUAL                   0.392  f5:+0.000, f6:-0.000, f11:+0.000
#   ROBO                   0.535  f4:+0.001, f7:-0.001, f2:-0.001
#   SOXX                   0.756  f8:-0.003, f10:-0.002, f3:+0.002
#   SPGP                   0.247  f10:-0.001, f5:+0.001, f15:-0.000
#   URA                    0.191  f8:-0.002, f15:-0.001, f7:-0.001
#   VEGI                   0.377  f8:-0.001, f14:-0.001, f6:+0.001
#   VLUE                   0.375  f2:-0.001, f15:+0.001, f11:-0.000
#   VTV                    0.798  f3:-0.001, f5:+0.000, f15:+0.000
#   VUG                    0.656  f3:+0.001, f15:-0.000, f4:-0.000
#   WOOD                   0.200  f4:+0.001, f6:+0.001, f8:-0.001
#   XAR                    0.571  f7:-0.002, f5:+0.002, f9:-0.001
#   XBI                    0.445  f3:-0.002, f14:-0.002, f7:+0.001
#   XLE                    0.894  f5:+0.003, f4:-0.003, f2:-0.002
#   XLF                    0.642  f8:+0.001, f4:+0.001, f13:-0.001
#   XLK                    0.622  f3:+0.001, f6:-0.001, f11:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.454, purity=0.728
#   AI Infrastructure: 3 ETFs, avg R²=0.461, purity=0.791
#   Clean Energy: 3 ETFs, avg R²=0.216, purity=0.844
#   Cybersecurity: 2 ETFs, avg R²=0.365, purity=0.947
#   Defense: 3 ETFs, avg R²=0.630, purity=0.997
#   Fintech: 3 ETFs, avg R²=0.535, purity=0.829
#   US Infrastructure: 2 ETFs, avg R²=0.665, purity=0.806
#   Agribusiness: 3 ETFs, avg R²=0.460, purity=0.748
#   Critical Minerals: 3 ETFs, avg R²=0.248, purity=0.709
#   Water: 3 ETFs, avg R²=0.644, purity=0.930
#   Timber & Forestry: 2 ETFs, avg R²=0.248, purity=0.921
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.427, 0.540]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 6/25: 2021-06-25
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2021-06-25 (expanding, 181 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.985
#   top eigenvalues:   [59.7 31.  23.5 21.3 18.9 15.8 13.9 13.  11.2 10.6  9.7  9.4  9.   8.8
#   8.4]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.573  f3:+0.003, f13:-0.002, f6:+0.001
#   BOTZ                   0.430  f4:+0.001, f6:+0.001, f2:-0.001
#   CGW                    0.584  f4:+0.001, f1:-0.001, f8:+0.001
#   CIBR                   0.362  f12:+0.002, f10:-0.001, f9:-0.001
#   COPX                   0.294  f6:+0.002, f13:-0.001, f2:-0.001
#   CUT                    0.293  f4:+0.001, f7:-0.001, f6:+0.001
#   FINX                   0.419  f3:+0.002, f12:+0.001, f2:+0.001
#   FIW                    0.650  f3:-0.001, f4:+0.001, f8:+0.001
#   HACK                   0.297  f12:+0.002, f9:-0.001, f6:+0.001
#   ICLN                   0.197  f6:+0.002, f7:-0.002, f2:+0.001
#   IFRA                   0.572  f8:+0.001, f1:-0.001, f6:+0.001
#   IGPT                   0.228  f12:+0.001, f3:+0.001, f4:-0.001
#   IGV                    0.428  f3:+0.001, f12:+0.001, f11:+0.001
#   IPAY                   0.558  f3:+0.001, f5:+0.001, f12:+0.001
#   IRBO                   0.371  f3:+0.001, f8:+0.001, f10:-0.001
#   ITA                    0.657  f5:+0.002, f9:-0.002, f7:-0.002
#   IUSG                   0.362  f3:+0.000, f10:+0.000, f6:-0.000
#   KRE                    0.681  f13:-0.001, f14:-0.001, f12:+0.001
#   LIT                    0.188  f8:+0.002, f12:-0.002, f6:+0.001
#   MOO                    0.371  f11:-0.001, f3:-0.001, f5:+0.001
#   MTUM                   0.149  f3:+0.000, f11:-0.000, f4:-0.000
#   PAVE                   0.741  f5:+0.002, f8:+0.001, f4:+0.001
#   PBJ                    0.642  f3:-0.002, f12:+0.001, f15:-0.001
#   PBW                    0.141  f8:+0.002, f12:-0.001, f6:+0.001
#   PHO                    0.663  f4:+0.001, f3:-0.001, f7:-0.001
#   PPA                    0.635  f5:+0.002, f7:-0.001, f9:-0.001
#   QCLN                   0.202  f8:+0.002, f11:-0.001, f6:+0.001
#   QTUM                   0.370  f8:+0.001, f3:+0.001, f10:-0.001
#   QUAL                   0.383  f5:+0.000, f12:+0.000, f6:-0.000
#   ROBO                   0.524  f4:+0.001, f2:-0.001, f10:-0.001
#   SOXX                   0.767  f8:+0.003, f10:-0.002, f3:+0.002
#   SPGP                   0.239  f10:-0.001, f5:+0.001, f9:-0.000
#   URA                    0.180  f8:+0.002, f6:+0.001, f5:+0.001
#   VEGI                   0.380  f8:+0.001, f14:-0.001, f3:-0.001
#   VLUE                   0.297  f2:-0.001, f11:-0.000, f3:-0.000
#   VTV                    0.752  f3:-0.001, f5:+0.000, f2:-0.000
#   VUG                    0.584  f3:+0.001, f2:+0.000, f12:+0.000
#   WOOD                   0.185  f4:+0.001, f6:+0.001, f8:+0.001
#   XAR                    0.543  f7:-0.002, f5:+0.002, f9:-0.001
#   XBI                    0.430  f3:-0.002, f8:-0.002, f2:-0.001
#   XLE                    0.886  f4:-0.004, f5:+0.003, f8:+0.002
#   XLF                    0.567  f8:-0.001, f4:+0.001, f6:-0.001
#   XLK                    0.604  f3:+0.001, f8:+0.001, f11:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.442, purity=0.738
#   AI Infrastructure: 3 ETFs, avg R²=0.455, purity=0.793
#   Clean Energy: 3 ETFs, avg R²=0.180, purity=0.793
#   Cybersecurity: 2 ETFs, avg R²=0.329, purity=0.955
#   Defense: 3 ETFs, avg R²=0.612, purity=0.997
#   Fintech: 3 ETFs, avg R²=0.516, purity=0.847
#   US Infrastructure: 2 ETFs, avg R²=0.656, purity=0.825
#   Agribusiness: 3 ETFs, avg R²=0.464, purity=0.757
#   Critical Minerals: 3 ETFs, avg R²=0.221, purity=0.797
#   Water: 3 ETFs, avg R²=0.632, purity=0.866
#   Timber & Forestry: 2 ETFs, avg R²=0.239, purity=0.928
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.597, 0.474]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 7/25: 2021-09-24
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2021-09-24 (expanding, 194 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.173
#   top eigenvalues:   [56.6 32.  23.2 20.2 18.  15.1 13.3 12.4 10.6 10.2  9.2  8.9  8.5  8.4
#   8. ]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.543  f3:+0.003, f5:-0.001, f13:-0.001
#   BOTZ                   0.391  f4:+0.002, f6:+0.001, f10:-0.001
#   CGW                    0.584  f4:+0.001, f8:+0.001, f1:-0.001
#   CIBR                   0.327  f12:+0.002, f10:-0.001, f11:-0.001
#   COPX                   0.292  f2:-0.002, f6:+0.002, f9:+0.001
#   CUT                    0.295  f4:+0.001, f7:-0.001, f8:+0.001
#   FINX                   0.392  f3:+0.001, f2:+0.001, f12:+0.001
#   FIW                    0.656  f8:+0.001, f3:-0.001, f4:+0.001
#   HACK                   0.263  f12:+0.001, f9:-0.001, f11:-0.001
#   ICLN                   0.186  f6:+0.002, f8:+0.001, f7:-0.001
#   IFRA                   0.576  f8:+0.001, f1:-0.001, f13:-0.001
#   IGPT                   0.188  f12:+0.001, f3:+0.001, f4:-0.001
#   IGV                    0.413  f3:+0.001, f11:-0.001, f12:+0.001
#   IPAY                   0.543  f3:+0.001, f12:+0.001, f1:-0.001
#   IRBO                   0.349  f3:+0.001, f8:+0.001, f5:-0.001
#   ITA                    0.644  f5:+0.002, f9:-0.002, f7:-0.001
#   IUSG                   0.355  f3:+0.000, f2:+0.000, f10:+0.000
#   KRE                    0.661  f13:-0.002, f12:+0.001, f6:-0.001
#   LIT                    0.174  f8:+0.002, f6:+0.001, f12:-0.001
#   MOO                    0.348  f5:+0.001, f11:+0.001, f3:-0.001
#   MTUM                   0.121  f3:+0.000, f11:+0.000, f4:-0.000
#   PAVE                   0.732  f5:+0.002, f8:+0.001, f4:+0.001
#   PBJ                    0.594  f3:-0.002, f12:+0.001, f15:-0.001
#   PBW                    0.130  f8:+0.002, f6:+0.001, f12:-0.001
#   PHO                    0.667  f4:+0.001, f3:-0.001, f5:+0.001
#   PPA                    0.632  f5:+0.002, f7:-0.001, f9:-0.001
#   QCLN                   0.190  f8:+0.002, f11:+0.001, f6:+0.001
#   QTUM                   0.378  f8:+0.001, f3:+0.001, f10:-0.001
#   QUAL                   0.345  f5:+0.000, f6:-0.000, f12:+0.000
#   ROBO                   0.496  f4:+0.001, f8:+0.001, f10:-0.001
#   SOXX                   0.770  f8:+0.003, f10:-0.003, f3:+0.002
#   SPGP                   0.231  f10:-0.001, f5:+0.001, f15:+0.000
#   URA                    0.153  f8:+0.003, f6:+0.002, f5:+0.001
#   VEGI                   0.362  f8:+0.001, f2:-0.001, f5:+0.001
#   VLUE                   0.291  f2:-0.001, f11:+0.000, f10:-0.000
#   VTV                    0.751  f3:-0.001, f5:+0.000, f2:-0.000
#   VUG                    0.584  f3:+0.001, f2:+0.000, f7:+0.000
#   WOOD                   0.179  f4:+0.001, f8:+0.001, f6:+0.001
#   XAR                    0.535  f7:-0.002, f5:+0.002, f9:-0.001
#   XBI                    0.415  f8:-0.002, f3:-0.002, f14:-0.002
#   XLE                    0.889  f4:-0.004, f5:+0.003, f2:-0.002
#   XLF                    0.578  f8:-0.001, f13:-0.001, f6:-0.001
#   XLK                    0.574  f3:+0.001, f11:-0.001, f12:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.412, purity=0.751
#   AI Infrastructure: 3 ETFs, avg R²=0.445, purity=0.780
#   Clean Energy: 3 ETFs, avg R²=0.169, purity=0.908
#   Cybersecurity: 2 ETFs, avg R²=0.295, purity=0.938
#   Defense: 3 ETFs, avg R²=0.604, purity=0.997
#   Fintech: 3 ETFs, avg R²=0.493, purity=0.841
#   US Infrastructure: 2 ETFs, avg R²=0.654, purity=0.827
#   Agribusiness: 3 ETFs, avg R²=0.435, purity=0.691
#   Critical Minerals: 3 ETFs, avg R²=0.207, purity=0.801
#   Water: 3 ETFs, avg R²=0.636, purity=0.851
#   Timber & Forestry: 2 ETFs, avg R²=0.237, purity=0.930
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.470, 0.521]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 8/25: 2021-12-31
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2021-12-31 (expanding, 208 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.058
#   top eigenvalues:   [54.1 33.3 22.9 19.7 16.8 14.7 12.8 12.  10.7 10.   9.   8.5  8.2  8.1
#   7.7]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.497  f3:+0.002, f14:+0.002, f10:+0.002
#   BOTZ                   0.365  f4:+0.002, f10:-0.001, f9:-0.001
#   CGW                    0.589  f4:+0.001, f8:+0.001, f1:-0.001
#   CIBR                   0.329  f12:+0.002, f10:-0.001, f7:-0.001
#   COPX                   0.275  f6:+0.002, f2:-0.002, f4:+0.002
#   CUT                    0.343  f4:+0.001, f8:+0.001, f3:-0.001
#   FINX                   0.402  f12:+0.001, f3:+0.001, f8:-0.001
#   FIW                    0.656  f8:+0.001, f3:-0.001, f4:+0.001
#   HACK                   0.277  f12:+0.002, f15:+0.001, f10:-0.001
#   ICLN                   0.192  f6:+0.002, f7:-0.001, f8:+0.001
#   IFRA                   0.569  f8:+0.001, f1:-0.001, f13:-0.001
#   IGPT                   0.245  f12:+0.002, f15:+0.001, f14:+0.001
#   IGV                    0.434  f12:+0.001, f3:+0.001, f15:+0.001
#   IPAY                   0.542  f12:+0.001, f8:-0.001, f1:-0.001
#   IRBO                   0.328  f3:+0.001, f8:+0.001, f10:-0.001
#   ITA                    0.627  f5:+0.002, f9:-0.002, f2:-0.002
#   IUSG                   0.401  f3:+0.000, f2:+0.000, f10:+0.000
#   KRE                    0.627  f13:-0.002, f6:-0.001, f11:+0.001
#   LIT                    0.190  f6:+0.002, f8:+0.002, f12:-0.001
#   MOO                    0.339  f5:+0.001, f3:-0.001, f8:+0.001
#   MTUM                   0.106  f11:+0.000, f3:+0.000, f6:+0.000
#   PAVE                   0.721  f5:+0.002, f8:+0.001, f4:+0.001
#   PBJ                    0.596  f3:-0.002, f15:-0.001, f13:+0.001
#   PBW                    0.147  f8:+0.002, f6:+0.002, f10:+0.001
#   PHO                    0.684  f4:+0.001, f3:-0.001, f5:+0.001
#   PPA                    0.623  f5:+0.001, f2:-0.001, f7:-0.001
#   QCLN                   0.209  f8:+0.002, f12:-0.002, f6:+0.002
#   QTUM                   0.388  f8:+0.001, f10:-0.001, f3:+0.001
#   QUAL                   0.333  f5:+0.000, f12:+0.000, f6:-0.000
#   ROBO                   0.489  f4:+0.002, f8:+0.001, f10:-0.001
#   SOXX                   0.789  f8:+0.003, f10:-0.003, f3:+0.002
#   SPGP                   0.275  f10:-0.001, f5:+0.001, f15:+0.001
#   URA                    0.128  f8:+0.003, f6:+0.002, f5:+0.001
#   VEGI                   0.346  f8:+0.001, f2:-0.001, f5:+0.001
#   VLUE                   0.303  f2:-0.001, f10:-0.000, f7:+0.000
#   VTV                    0.764  f3:-0.001, f5:+0.000, f2:-0.000
#   VUG                    0.612  f3:+0.001, f2:+0.000, f15:+0.000
#   WOOD                   0.206  f4:+0.001, f8:+0.001, f6:+0.001
#   XAR                    0.515  f2:-0.001, f5:+0.001, f7:-0.001
#   XBI                    0.433  f14:-0.002, f3:-0.002, f8:-0.002
#   XLE                    0.889  f5:+0.003, f4:-0.003, f6:+0.002
#   XLF                    0.573  f8:-0.001, f11:+0.001, f6:-0.001
#   XLK                    0.587  f3:+0.001, f12:+0.001, f8:+0.000
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.394, purity=0.816
#   AI Infrastructure: 3 ETFs, avg R²=0.474, purity=0.732
#   Clean Energy: 3 ETFs, avg R²=0.183, purity=0.894
#   Cybersecurity: 2 ETFs, avg R²=0.303, purity=0.965
#   Defense: 3 ETFs, avg R²=0.588, purity=0.933
#   Fintech: 3 ETFs, avg R²=0.480, purity=0.751
#   US Infrastructure: 2 ETFs, avg R²=0.645, purity=0.831
#   Agribusiness: 3 ETFs, avg R²=0.427, purity=0.756
#   Critical Minerals: 3 ETFs, avg R²=0.198, purity=0.809
#   Water: 3 ETFs, avg R²=0.643, purity=0.854
#   Timber & Forestry: 2 ETFs, avg R²=0.274, purity=0.943
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.469, 0.522]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 9/25: 2022-03-25
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2022-03-25 (expanding, 220 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.955
#   top eigenvalues:   [53.6 33.1 22.5 20.8 16.6 14.8 12.6 12.1 10.4  9.7  9.1  8.6  8.1  8.
#   7.6]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.488  f4:+0.002, f3:+0.002, f10:+0.002
#   BOTZ                   0.342  f4:+0.001, f8:+0.001, f6:+0.001
#   CGW                    0.612  f8:+0.001, f3:-0.001, f1:-0.001
#   CIBR                   0.380  f12:+0.002, f13:-0.001, f10:-0.001
#   COPX                   0.254  f6:+0.002, f8:+0.002, f5:-0.002
#   CUT                    0.294  f8:+0.001, f2:-0.001, f4:+0.001
#   FINX                   0.437  f13:-0.001, f12:+0.001, f4:+0.001
#   FIW                    0.686  f8:+0.001, f3:-0.001, f5:-0.001
#   HACK                   0.340  f12:+0.002, f13:-0.001, f6:+0.001
#   ICLN                   0.208  f8:+0.002, f12:-0.002, f2:+0.002
#   IFRA                   0.579  f8:+0.001, f1:-0.001, f6:+0.001
#   IGPT                   0.259  f13:-0.002, f12:+0.001, f9:+0.001
#   IGV                    0.505  f12:+0.002, f13:-0.001, f3:+0.001
#   IPAY                   0.504  f6:-0.001, f12:+0.001, f8:-0.001
#   IRBO                   0.349  f2:-0.001, f11:+0.001, f12:+0.001
#   ITA                    0.630  f5:-0.002, f8:+0.001, f13:-0.001
#   IUSG                   0.418  f3:+0.000, f2:+0.000, f7:+0.000
#   KRE                    0.620  f14:-0.002, f6:-0.002, f15:-0.001
#   LIT                    0.185  f6:+0.002, f12:-0.002, f4:+0.001
#   MOO                    0.324  f5:-0.001, f12:-0.001, f8:+0.001
#   MTUM                   0.133  f11:+0.000, f3:+0.000, f7:-0.000
#   PAVE                   0.705  f5:-0.002, f8:+0.001, f3:-0.001
#   PBJ                    0.615  f3:-0.001, f11:+0.001, f4:-0.001
#   PBW                    0.158  f8:+0.002, f6:+0.002, f10:+0.002
#   PHO                    0.702  f3:-0.001, f4:+0.001, f8:+0.001
#   PPA                    0.622  f5:-0.001, f8:+0.001, f13:-0.001
#   QCLN                   0.214  f8:+0.002, f6:+0.002, f12:-0.001
#   QTUM                   0.404  f11:+0.001, f8:+0.001, f3:+0.001
#   QUAL                   0.317  f5:-0.000, f7:+0.000, f1:-0.000
#   ROBO                   0.498  f4:+0.001, f8:+0.001, f2:-0.001
#   SOXX                   0.797  f7:+0.002, f10:-0.002, f11:+0.002
#   SPGP                   0.301  f5:-0.001, f10:-0.001, f15:+0.000
#   URA                    0.126  f8:+0.002, f6:+0.002, f5:-0.001
#   VEGI                   0.309  f5:-0.001, f8:+0.001, f12:-0.001
#   VLUE                   0.335  f2:-0.001, f10:-0.000, f11:+0.000
#   VTV                    0.780  f3:-0.001, f5:-0.000, f1:-0.000
#   VUG                    0.604  f3:+0.001, f12:+0.000, f2:+0.000
#   WOOD                   0.167  f4:+0.001, f2:-0.001, f6:+0.001
#   XAR                    0.520  f13:-0.002, f8:+0.002, f5:-0.001
#   XBI                    0.444  f13:+0.002, f8:-0.002, f12:-0.001
#   XLE                    0.886  f4:-0.004, f5:-0.003, f15:-0.002
#   XLF                    0.646  f6:-0.001, f15:-0.001, f7:-0.001
#   XLK                    0.583  f3:+0.001, f12:+0.001, f7:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.396, purity=0.753
#   AI Infrastructure: 3 ETFs, avg R²=0.487, purity=0.623
#   Clean Energy: 3 ETFs, avg R²=0.193, purity=0.855
#   Cybersecurity: 2 ETFs, avg R²=0.360, purity=0.965
#   Defense: 3 ETFs, avg R²=0.591, purity=0.995
#   Fintech: 3 ETFs, avg R²=0.476, purity=0.673
#   US Infrastructure: 2 ETFs, avg R²=0.642, purity=0.831
#   Agribusiness: 3 ETFs, avg R²=0.416, purity=0.740
#   Critical Minerals: 3 ETFs, avg R²=0.188, purity=0.852
#   Water: 3 ETFs, avg R²=0.667, purity=0.906
#   Timber & Forestry: 2 ETFs, avg R²=0.230, purity=0.914
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.428, 0.430]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 10/25: 2022-06-24
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2022-06-24 (expanding, 233 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.817
#   top eigenvalues:   [53.3 32.2 22.7 20.5 16.7 15.3 12.5 11.9 10.4  9.7  9.1  8.5  8.3  8.2
#   7.8]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.438  f10:+0.002, f6:+0.002, f4:+0.002
#   BOTZ                   0.335  f4:+0.001, f2:-0.001, f5:-0.001
#   CGW                    0.599  f1:-0.001, f13:+0.001, f8:-0.001
#   CIBR                   0.359  f13:-0.002, f14:-0.001, f15:+0.001
#   COPX                   0.239  f5:-0.003, f2:-0.002, f14:-0.002
#   CUT                    0.276  f8:-0.001, f4:+0.001, f2:-0.001
#   FINX                   0.450  f15:+0.001, f3:+0.001, f4:+0.001
#   FIW                    0.691  f8:-0.001, f5:-0.001, f3:-0.001
#   HACK                   0.314  f13:-0.002, f15:+0.001, f14:-0.001
#   ICLN                   0.239  f13:+0.003, f2:+0.002, f8:-0.002
#   IFRA                   0.583  f8:-0.001, f1:-0.001, f5:-0.001
#   IGPT                   0.219  f15:+0.001, f13:-0.001, f12:-0.001
#   IGV                    0.501  f13:-0.001, f15:+0.001, f3:+0.001
#   IPAY                   0.508  f6:-0.001, f9:+0.001, f1:-0.001
#   IRBO                   0.387  f2:-0.001, f15:+0.001, f12:-0.001
#   ITA                    0.613  f6:-0.002, f8:-0.002, f9:-0.001
#   IUSG                   0.437  f3:+0.000, f10:+0.000, f7:-0.000
#   KRE                    0.595  f6:-0.001, f5:+0.001, f4:+0.001
#   LIT                    0.175  f13:+0.002, f11:+0.001, f6:+0.001
#   MOO                    0.342  f11:+0.001, f5:-0.001, f12:+0.001
#   MTUM                   0.114  f14:+0.000, f11:+0.000, f7:+0.000
#   PAVE                   0.697  f5:-0.002, f10:+0.001, f8:-0.001
#   PBJ                    0.624  f3:-0.001, f13:-0.001, f14:+0.001
#   PBW                    0.157  f6:+0.002, f13:+0.002, f10:+0.002
#   PHO                    0.695  f4:+0.001, f5:-0.001, f3:-0.001
#   PPA                    0.600  f8:-0.001, f6:-0.001, f1:-0.001
#   QCLN                   0.206  f6:+0.002, f13:+0.002, f8:-0.001
#   QTUM                   0.436  f11:+0.001, f7:-0.001, f2:-0.001
#   QUAL                   0.339  f5:-0.000, f13:-0.000, f7:-0.000
#   ROBO                   0.496  f4:+0.001, f2:-0.001, f8:-0.001
#   SOXX                   0.811  f7:-0.003, f10:-0.002, f4:+0.002
#   SPGP                   0.294  f5:-0.001, f10:-0.001, f15:+0.000
#   URA                    0.132  f5:-0.002, f4:-0.001, f11:+0.001
#   VEGI                   0.304  f12:+0.001, f5:-0.001, f11:+0.001
#   VLUE                   0.374  f2:-0.001, f3:-0.001, f14:+0.001
#   VTV                    0.805  f3:-0.001, f15:-0.000, f5:-0.000
#   VUG                    0.642  f3:+0.001, f15:+0.000, f12:-0.000
#   WOOD                   0.164  f5:-0.001, f4:+0.001, f2:-0.001
#   XAR                    0.521  f8:-0.002, f6:-0.002, f13:-0.002
#   XBI                    0.482  f3:-0.002, f13:+0.002, f8:+0.002
#   XLE                    0.883  f4:-0.004, f5:-0.004, f15:-0.002
#   XLF                    0.687  f6:-0.001, f15:-0.001, f4:+0.001
#   XLK                    0.597  f3:+0.001, f7:-0.001, f12:-0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.406, purity=0.830
#   AI Infrastructure: 3 ETFs, avg R²=0.489, purity=0.626
#   Clean Energy: 3 ETFs, avg R²=0.201, purity=0.863
#   Cybersecurity: 2 ETFs, avg R²=0.336, purity=0.996
#   Defense: 3 ETFs, avg R²=0.578, purity=0.899
#   Fintech: 3 ETFs, avg R²=0.466, purity=0.525
#   US Infrastructure: 2 ETFs, avg R²=0.640, purity=0.901
#   Agribusiness: 3 ETFs, avg R²=0.423, purity=0.742
#   Critical Minerals: 3 ETFs, avg R²=0.182, purity=0.692
#   Water: 3 ETFs, avg R²=0.662, purity=0.736
#   Timber & Forestry: 2 ETFs, avg R²=0.220, purity=0.896
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.426, 0.475]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 11/25: 2022-09-30
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2022-09-30 (expanding, 247 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.793
#   top eigenvalues:   [52.1 32.9 22.2 20.3 16.6 15.3 12.6 11.4 10.3  9.4  8.7  8.5  8.2  8.
#   7.7]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.442  f10:+0.002, f6:+0.002, f2:-0.002
#   BOTZ                   0.334  f2:-0.001, f5:-0.001, f4:+0.001
#   CGW                    0.613  f5:-0.001, f1:-0.001, f8:-0.001
#   CIBR                   0.330  f14:+0.002, f12:-0.002, f8:-0.001
#   COPX                   0.280  f5:-0.003, f13:+0.002, f2:-0.002
#   CUT                    0.282  f5:-0.001, f8:-0.001, f9:+0.001
#   FINX                   0.462  f12:-0.002, f9:+0.001, f3:+0.001
#   FIW                    0.711  f5:-0.001, f8:-0.001, f7:-0.001
#   HACK                   0.288  f14:+0.002, f12:-0.002, f4:-0.001
#   ICLN                   0.272  f13:+0.002, f14:-0.002, f2:+0.002
#   IFRA                   0.600  f8:-0.001, f1:-0.001, f5:-0.001
#   IGPT                   0.229  f12:-0.002, f14:+0.001, f9:+0.001
#   IGV                    0.500  f14:+0.001, f12:-0.001, f9:+0.001
#   IPAY                   0.503  f6:-0.001, f9:+0.001, f11:-0.001
#   IRBO                   0.399  f2:-0.002, f12:-0.001, f6:+0.001
#   ITA                    0.600  f6:-0.002, f8:-0.002, f9:-0.001
#   IUSG                   0.392  f3:+0.000, f12:-0.000, f14:-0.000
#   KRE                    0.611  f4:+0.001, f15:-0.001, f5:+0.001
#   LIT                    0.170  f14:-0.002, f13:+0.001, f6:+0.001
#   MOO                    0.360  f5:-0.001, f13:+0.001, f11:+0.001
#   MTUM                   0.099  f11:+0.000, f14:-0.000, f7:+0.000
#   PAVE                   0.711  f5:-0.002, f10:+0.001, f8:-0.001
#   PBJ                    0.592  f3:-0.001, f13:-0.001, f8:-0.001
#   PBW                    0.175  f6:+0.002, f13:+0.002, f15:+0.001
#   PHO                    0.712  f5:-0.001, f4:+0.001, f3:-0.001
#   PPA                    0.589  f6:-0.001, f8:-0.001, f14:+0.001
#   QCLN                   0.208  f6:+0.002, f14:-0.002, f15:+0.001
#   QTUM                   0.457  f2:-0.001, f11:+0.001, f6:+0.001
#   QUAL                   0.325  f5:-0.000, f13:-0.000, f14:+0.000
#   ROBO                   0.504  f2:-0.001, f5:-0.001, f12:-0.001
#   SOXX                   0.822  f10:-0.002, f7:-0.002, f9:-0.002
#   SPGP                   0.269  f5:-0.001, f10:-0.001, f8:+0.000
#   URA                    0.172  f5:-0.002, f4:-0.002, f11:+0.001
#   VEGI                   0.341  f5:-0.001, f11:+0.001, f13:+0.001
#   VLUE                   0.397  f2:-0.001, f11:+0.001, f3:-0.001
#   VTV                    0.804  f3:-0.001, f6:-0.000, f5:-0.000
#   VUG                    0.618  f3:+0.001, f12:-0.000, f6:+0.000
#   WOOD                   0.173  f5:-0.001, f2:-0.001, f9:+0.001
#   XAR                    0.491  f14:+0.002, f8:-0.001, f6:-0.001
#   XBI                    0.477  f14:-0.002, f3:-0.002, f8:+0.002
#   XLE                    0.879  f4:-0.004, f5:-0.003, f15:-0.002
#   XLF                    0.683  f6:-0.001, f4:+0.001, f15:-0.001
#   XLK                    0.584  f3:+0.001, f7:-0.001, f12:-0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.412, purity=0.867
#   AI Infrastructure: 3 ETFs, avg R²=0.502, purity=0.515
#   Clean Energy: 3 ETFs, avg R²=0.218, purity=0.798
#   Cybersecurity: 2 ETFs, avg R²=0.309, purity=0.986
#   Defense: 3 ETFs, avg R²=0.560, purity=0.929
#   Fintech: 3 ETFs, avg R²=0.469, purity=0.550
#   US Infrastructure: 2 ETFs, avg R²=0.655, purity=0.900
#   Agribusiness: 3 ETFs, avg R²=0.431, purity=0.638
#   Critical Minerals: 3 ETFs, avg R²=0.208, purity=0.703
#   Water: 3 ETFs, avg R²=0.678, purity=0.821
#   Timber & Forestry: 2 ETFs, avg R²=0.227, purity=0.927
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.399, 0.410]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 12/25: 2022-12-30
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2022-12-30 (expanding, 260 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.775
# ...
#   XBI                    0.372  f9:-0.003, f12:-0.002, f13:-0.001
#   XLE                    0.856  f4:-0.005, f8:-0.002, f3:-0.002
#   XLF                    0.696  f6:-0.001, f10:-0.001, f5:-0.001
#   XLK                    0.639  f8:-0.001, f4:+0.001, f15:-0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.421, purity=0.770
#   AI Infrastructure: 3 ETFs, avg R²=0.494, purity=0.652
#   Clean Energy: 3 ETFs, avg R²=0.253, purity=0.851
#   Cybersecurity: 2 ETFs, avg R²=0.238, purity=1.000
#   Defense: 3 ETFs, avg R²=0.461, purity=0.949
#   Fintech: 3 ETFs, avg R²=0.405, purity=0.826
#   US Infrastructure: 2 ETFs, avg R²=0.683, purity=0.913
#   Agribusiness: 3 ETFs, avg R²=0.450, purity=0.852
#   Critical Minerals: 3 ETFs, avg R²=0.256, purity=0.825
#   Water: 3 ETFs, avg R²=0.620, purity=0.942
#   Timber & Forestry: 2 ETFs, avg R²=0.249, purity=0.999
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.371, 0.424]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 24/25: 2025-12-26
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2025-12-26 (expanding, 416 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.517
#   top eigenvalues:   [51.8 26.1 20.5 18.5 14.7 14.1 10.7 10.1  8.5  8.3  7.5  7.2  7.1  6.4
#   6.4]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.339  f9:-0.002, f4:+0.002, f2:-0.001
#   BOTZ                   0.323  f5:+0.001, f6:-0.001, f13:+0.001
#   CGW                    0.575  f13:+0.001, f5:+0.001, f1:-0.001
#   CIBR                   0.270  f12:+0.002, f7:+0.001, f11:+0.001
#   COPX                   0.362  f13:+0.004, f14:+0.002, f5:+0.002
#   CUT                    0.289  f11:+0.001, f13:+0.001, f2:-0.001
#   FINX                   0.383  f7:+0.002, f4:+0.001, f13:+0.001
#   FIW                    0.630  f6:-0.001, f5:+0.001, f1:-0.001
#   HACK                   0.225  f12:+0.002, f7:+0.001, f11:+0.001
#   ICLN                   0.267  f5:+0.002, f13:+0.002, f11:+0.002
#   IFRA                   0.654  f7:-0.001, f9:-0.001, f5:+0.001
#   IGPT                   0.186  f12:+0.001, f7:+0.001, f11:+0.001
#   IGV                    0.493  f7:+0.002, f12:+0.002, f9:-0.001
#   IPAY                   0.481  f7:+0.002, f5:-0.001, f6:-0.001
#   IRBO                   0.405  f2:-0.001, f11:+0.001, f5:+0.001
#   ITA                    0.485  f6:-0.002, f12:+0.001, f3:-0.001
#   IUSG                   0.475  f14:-0.000, f3:-0.000, f4:+0.000
#   KRE                    0.677  f10:-0.002, f8:-0.002, f5:-0.001
#   LIT                    0.200  f13:+0.002, f5:+0.002, f12:-0.001
#   MOO                    0.381  f4:-0.001, f14:+0.001, f13:+0.001
#   MTUM                   0.096  f11:+0.000, f15:-0.000, f3:-0.000
#   PAVE                   0.714  f6:-0.002, f9:-0.001, f7:-0.001
#   PBJ                    0.576  f15:-0.001, f12:+0.001, f2:+0.001
#   PBW                    0.202  f5:+0.003, f2:-0.002, f13:+0.001
#   PHO                    0.653  f6:-0.001, f5:+0.001, f1:-0.001
#   PPA                    0.484  f6:-0.001, f12:+0.001, f7:-0.001
#   QCLN                   0.237  f5:+0.003, f6:+0.001, f14:+0.001
#   QTUM                   0.471  f12:+0.001, f2:-0.001, f7:-0.001
#   QUAL                   0.284  f6:-0.000, f7:+0.000, f13:-0.000
#   ROBO                   0.520  f5:+0.001, f2:-0.001, f11:+0.001
#   SOXX                   0.824  f5:+0.003, f9:+0.002, f2:-0.002
#   SPGP                   0.274  f6:-0.001, f10:-0.001, f14:+0.000
#   URA                    0.178  f9:-0.003, f4:-0.002, f5:+0.002
#   VEGI                   0.332  f4:-0.001, f14:+0.001, f6:-0.001
#   VLUE                   0.379  f7:-0.001, f13:-0.001, f2:-0.001
#   VTV                    0.787  f1:-0.001, f4:-0.000, f6:-0.000
#   VUG                    0.664  f7:+0.000, f4:+0.000, f3:-0.000
#   WOOD                   0.213  f5:+0.001, f13:+0.001, f2:-0.001
#   XAR                    0.372  f6:-0.001, f7:-0.001, f3:-0.001
#   XBI                    0.419  f9:+0.003, f10:-0.002, f12:-0.002
#   XLE                    0.855  f4:-0.005, f3:-0.002, f8:-0.002
#   XLF                    0.693  f5:-0.001, f10:-0.001, f6:-0.001
#   XLK                    0.642  f12:+0.001, f8:-0.001, f4:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.416, purity=0.850
#   AI Infrastructure: 3 ETFs, avg R²=0.493, purity=0.605
#   Clean Energy: 3 ETFs, avg R²=0.235, purity=0.883
#   Cybersecurity: 2 ETFs, avg R²=0.247, purity=0.999
#   Defense: 3 ETFs, avg R²=0.447, purity=0.890
#   Fintech: 3 ETFs, avg R²=0.401, purity=0.719
#   US Infrastructure: 2 ETFs, avg R²=0.684, purity=0.861
#   Agribusiness: 3 ETFs, avg R²=0.430, purity=0.715
#   Critical Minerals: 3 ETFs, avg R²=0.247, purity=0.783
#   Water: 3 ETFs, avg R²=0.619, purity=0.882
#   Timber & Forestry: 2 ETFs, avg R²=0.251, purity=0.900
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.335, 0.455]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
#
# ======================================================================
# rebalance 25/25: 2026-03-27
# ======================================================================
#
# [1/1] fitting RP-PCA as of 2026-03-27 (expanding, 429 weeks x 703 stocks)
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.469
#   top eigenvalues:   [51.7 27.8 20.7 17.9 16.2 14.1 11.8  9.9  8.6  8.2  7.5  7.2  7.   6.7
#   6.4]
#
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.339  f9:-0.002, f4:-0.002, f2:+0.001
#   BOTZ                   0.339  f5:-0.001, f13:+0.001, f4:-0.001
#   CGW                    0.588  f5:-0.001, f1:+0.001, f13:+0.001
#   CIBR                   0.292  f12:+0.002, f7:-0.001, f13:+0.001
#   COPX                   0.332  f12:-0.003, f5:-0.003, f11:+0.002
#   CUT                    0.308  f5:-0.001, f11:+0.001, f2:+0.001
#   FINX                   0.421  f7:-0.002, f5:+0.001, f2:+0.001
#   FIW                    0.626  f6:+0.001, f5:-0.001, f1:+0.001
#   HACK                   0.233  f12:+0.002, f7:-0.001, f13:+0.001
#   ICLN                   0.242  f5:-0.002, f13:+0.002, f11:+0.001
#   IFRA                   0.663  f9:-0.001, f2:-0.001, f5:-0.001
#   IGPT                   0.174  f13:+0.001, f9:+0.001, f11:+0.001
#   IGV                    0.530  f7:-0.002, f13:+0.001, f12:+0.001
#   IPAY                   0.503  f5:+0.002, f7:-0.001, f6:+0.001
#   IRBO                   0.415  f3:+0.001, f13:+0.001, f2:+0.001
#   ITA                    0.480  f6:+0.002, f11:-0.001, f7:+0.001
#   IUSG                   0.462  f7:-0.000, f4:-0.000, f3:+0.000
#   KRE                    0.668  f8:+0.002, f10:-0.002, f5:+0.001
#   LIT                    0.199  f5:-0.003, f12:-0.002, f13:+0.001
#   MOO                    0.381  f5:-0.001, f4:+0.001, f14:+0.001
#   MTUM                   0.086  f11:+0.000, f6:+0.000, f3:+0.000
#   PAVE                   0.723  f6:+0.002, f9:-0.001, f5:-0.001
#   PBJ                    0.556  f14:+0.001, f12:+0.001, f2:-0.001
#   PBW                    0.202  f5:-0.003, f6:-0.002, f2:+0.001
#   PHO                    0.650  f6:+0.001, f5:-0.001, f1:+0.001
#   PPA                    0.481  f6:+0.001, f11:-0.001, f7:+0.001
#   QCLN                   0.240  f5:-0.003, f6:-0.001, f3:+0.001
#   QTUM                   0.467  f3:+0.001, f5:-0.001, f12:+0.001
#   QUAL                   0.294  f6:+0.000, f15:-0.000, f9:+0.000
#   ROBO                   0.544  f5:-0.002, f13:+0.001, f2:+0.001
#   SOXX                   0.806  f5:-0.003, f12:+0.002, f9:+0.002
#   SPGP                   0.271  f6:+0.001, f10:-0.001, f9:+0.000
#   URA                    0.180  f9:-0.003, f5:-0.002, f12:-0.002
#   VEGI                   0.333  f5:-0.001, f4:+0.001, f14:+0.001
#   VLUE                   0.356  f7:+0.001, f5:-0.001, f9:+0.001
#   VTV                    0.788  f1:+0.000, f7:+0.000, f6:+0.000
#   VUG                    0.660  f7:-0.000, f4:-0.000, f3:+0.000
#   WOOD                   0.235  f5:-0.002, f11:+0.001, f2:+0.001
#   XAR                    0.359  f6:+0.001, f3:+0.001, f11:-0.001
#   XBI                    0.438  f9:+0.003, f10:-0.002, f7:+0.001
#   XLE                    0.864  f4:+0.004, f3:+0.002, f14:+0.002
#   XLF                    0.697  f5:+0.001, f6:+0.001, f10:-0.001
#   XLK                    0.634  f4:-0.001, f11:-0.001, f12:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.433, purity=0.835
#   AI Infrastructure: 3 ETFs, avg R²=0.482, purity=0.723
#   Clean Energy: 3 ETFs, avg R²=0.228, purity=0.883
#   Cybersecurity: 2 ETFs, avg R²=0.263, purity=0.999
#   Defense: 3 ETFs, avg R²=0.440, purity=0.938
#   Fintech: 3 ETFs, avg R²=0.421, purity=0.730
#   US Infrastructure: 2 ETFs, avg R²=0.693, purity=0.878
#   Agribusiness: 3 ETFs, avg R²=0.423, purity=0.822
#   Critical Minerals: 3 ETFs, avg R²=0.237, purity=0.908
#   Water: 3 ETFs, avg R²=0.621, purity=0.901
#   Timber & Forestry: 2 ETFs, avg R²=0.271, purity=0.997
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.396, 0.412]
#
# ranked candidates summary:
# theme
# AI Infrastructure    30
# Agribusiness         30
# Clean Energy         30
# Critical Minerals    30
# Cybersecurity        30
# Defense              30
# Fintech              30
# Robotics & AI        30
# Timber & Forestry    30
# US Infrastructure    30
# Water                30
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.797
#   top eigenvalues:   [78.8 46.9 27.6 19.6 18.3 16.7 14.3 12.7 11.4 11.  10.5 10.1  9.3  8.7
#   8.5]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.386
#   top eigenvalues:   [74.1 40.8 27.9 22.6 21.6 17.  16.5 14.2 13.3 12.  11.3 10.3 10.1  9.9
#   9.6]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.721
#   top eigenvalues:   [69.3 40.5 26.6 22.3 20.6 16.9 15.5 14.1 12.7 11.9 10.9 10.4  9.6  9.4
#   9.3]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      7.230
#   top eigenvalues:   [64.3 36.4 25.6 22.  20.4 17.1 14.6 13.6 12.3 11.4 10.5 10.   9.4  9.1
#   8.9]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.189
#   top eigenvalues:   [62.3 33.5 24.6 21.4 19.9 16.6 14.4 13.6 11.9 11.3 10.1 10.   9.4  9.2
#   8.8]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.985
#   top eigenvalues:   [59.7 31.  23.5 21.3 18.9 15.8 13.9 13.  11.2 10.6  9.7  9.4  9.   8.8
#   8.4]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.173
#   top eigenvalues:   [56.6 32.  23.2 20.2 18.  15.1 13.3 12.4 10.6 10.2  9.2  8.9  8.5  8.4
#   8. ]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      6.058
#   top eigenvalues:   [54.1 33.3 22.9 19.7 16.8 14.7 12.8 12.  10.7 10.   9.   8.5  8.2  8.1
#   7.7]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.955
#   top eigenvalues:   [53.6 33.1 22.5 20.8 16.6 14.8 12.6 12.1 10.4  9.7  9.1  8.6  8.1  8.
#   7.6]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.817
#   top eigenvalues:   [53.3 32.2 22.7 20.5 16.7 15.3 12.5 11.9 10.4  9.7  9.1  8.5  8.3  8.2
#   7.8]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.793
#   top eigenvalues:   [52.1 32.9 22.2 20.3 16.6 15.3 12.6 11.4 10.3  9.4  8.7  8.5  8.2  8.
#   7.7]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.775
#   top eigenvalues:   [51.7 30.8 22.3 20.5 16.7 15.4 12.4 11.2 10.2  9.2  8.9  8.4  8.1  7.8
#   7.4]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.356
#   top eigenvalues:   [50.2 29.3 23.4 19.7 16.2 15.1 11.9 11.2 10.2  9.1  8.7  8.3  7.9  7.6
#   7.3]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.184
#   top eigenvalues:   [50.4 28.3 23.  19.4 16.  14.8 11.8 11.1 10.2  9.1  8.5  8.3  7.9  7.4
#   7.2]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.055
#   top eigenvalues:   [51.1 27.3 22.5 18.6 15.6 14.5 11.4 10.8  9.8  8.9  8.3  8.1  7.8  7.3
#   7.2]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.091
#   top eigenvalues:   [49.4 26.6 21.9 20.2 15.5 14.5 11.2 10.7  9.5  8.6  8.2  7.8  7.6  7.2
#   7. ]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      4.925
#   top eigenvalues:   [49.1 25.3 21.4 19.9 15.2 14.3 10.9 10.5  9.2  8.4  8.2  7.7  7.5  7.
#   6.8]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.180
#   top eigenvalues:   [48.9 25.1 21.3 19.2 15.5 14.2 10.7 10.3  9.1  8.2  8.   7.6  7.4  7.
#   6.7]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.390
#   top eigenvalues:   [49.1 25.4 21.8 19.2 15.4 13.9 10.6 10.3  8.8  8.1  7.9  7.5  7.2  6.9
#   6.7]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.412
#   top eigenvalues:   [50.  26.1 21.6 18.9 15.1 14.3 10.5 10.1  8.6  8.1  7.8  7.4  7.2  6.8
#   6.6]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.264
#   top eigenvalues:   [48.4 27.1 21.6 18.3 15.3 14.4 10.4  9.9  8.6  8.3  7.9  7.3  7.1  6.6
#   6.5]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.342
#   top eigenvalues:   [51.4 26.6 21.4 19.  15.  14.4 10.5 10.   8.5  8.3  7.9  7.4  7.   6.6
#   6.4]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.346
#   top eigenvalues:   [51.3 26.1 21.1 18.6 14.7 14.2 10.6 10.1  8.4  8.4  7.7  7.3  7.   6.5
#   6.3]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.517
#   top eigenvalues:   [51.8 26.1 20.5 18.5 14.7 14.1 10.7 10.1  8.5  8.3  7.5  7.2  7.1  6.4
#   6.4]
# RP-PCA fitted: K=15, gamma=10.0
#   in-sample SR:      5.469
#   top eigenvalues:   [51.7 27.8 20.7 17.9 16.2 14.1 11.8  9.9  8.6  8.2  7.5  7.2  7.   6.7
#   6.4]
#
# factor identity drift (cosine similarity to the SAME factor_k, prior period):
#             mean    min
# factor
# factor_1   0.583 -0.999
# factor_10  0.511 -0.991
# factor_11  0.266 -0.984
# factor_12  0.411 -0.976
# factor_13  0.428 -0.986
# factor_14  0.364 -0.972
# factor_15  0.179 -0.935
# factor_2   0.319 -0.987
# factor_3   0.659 -0.997
# factor_4   0.582 -0.995
# factor_5   0.588 -0.978
# factor_6   0.579 -0.990
# factor_7   0.484 -0.983
# factor_8   0.164 -0.987
# factor_9   0.476 -0.997
#   near 1.0 = stable identity, safe to hold across rebalances
#   near 0 or negative = factor has rotated, re-underwrite before re-sizing
#
# ======================================================================
# WALK-FORWARD BACKTEST COMPLETE: 25 rebalances
# ======================================================================
#
# final cumulative growth of $1, by theme:
# Robotics & AI        0.727
# AI Infrastructure    1.319
# Clean Energy         0.757
# Cybersecurity        1.082
# Defense              1.413
# Fintech              0.894
# US Infrastructure    1.807
# Agribusiness         1.125
# Critical Minerals    1.152
# Water                1.093
# Timber & Forestry    0.667
#
# walk-forward backtest summary (genuinely out-of-sample, per rebalance period):
#             theme  n_periods  mean_ret_ann  vol_ann  sharpe  hit_rate
# US Infrastructure         25         0.114    0.206   0.555      0.48
#           Defense         25         0.077    0.221   0.348      0.52
# AI Infrastructure         25         0.073    0.255   0.287      0.48
# Critical Minerals         25         0.046    0.221   0.206      0.48
#      Agribusiness         25         0.043    0.226   0.190      0.56
#     Cybersecurity         25         0.043    0.258   0.168      0.48
#             Water         25         0.032    0.195   0.162      0.48
#           Fintech         25         0.016    0.268   0.058      0.36
#      Clean Energy         25        -0.008    0.282  -0.030      0.40
#     Robotics & AI         25        -0.013    0.288  -0.044      0.44
# Timber & Forestry         25        -0.033    0.259  -0.127      0.44

# %% [markdown]
# ## Step 5 (V2) -- Equity Curves

# %%
# -------------------- 5 (V2). Equity curves --------------------
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(11, 6))
wf_backtest['equity_curves'].plot(ax=ax)
ax.set_title('Walk-forward equity curves (genuinely out-of-sample, per theme)')
ax.set_ylabel('growth of $1')
ax.set_xlabel('rebalance date')
plt.tight_layout()
plt.savefig('outputs/fig_v2_walkforward_equity.png', dpi=150)
plt.show()

# %% [markdown]
# ## Step 6 (V2) -- Candidate-Level Null Test (Most Recent Rebalance)
#
# Directly answers: for the current period, is there actually genuine thematic exposure in the target universe for each theme, or would a random top-N look just as good? Uses the same point-in-time fit as the last backtest rebalance.

# %%
# -------------------- 6 (V2). Candidate null test, most recent period --------------------
from src.projection import synthetic_theme_returns, score_universe_v2, candidate_null_test
from src.theme_dna import label_theme_factors

last_d = rebalance_dates[-1]
wf_last = walkforward_fits[last_d]
dna_last = label_theme_factors(wf_last, etf_residuals.loc[:last_d], themes_config,
                                top_factors=TOP_FACTORS)
synth_last = synthetic_theme_returns(wf_last, dna_last['theme_factors'])
scores_last = score_universe_v2(tgt_residuals.loc[:last_d], synth_last)

null_test = candidate_null_test(scores_last, top_n=TOP_N, n_null_draws=1000)
# Out:
# labeling theme factors using 43 ETFs:
#   ETF                       R²  top factor weights
#   ------------------------------------------------------------
#   ARKF                   0.339  f9:-0.002, f4:-0.002, f2:+0.001
#   BOTZ                   0.339  f5:-0.001, f13:+0.001, f4:-0.001
#   CGW                    0.588  f5:-0.001, f1:+0.001, f13:+0.001
#   CIBR                   0.292  f12:+0.002, f7:-0.001, f13:+0.001
#   COPX                   0.332  f12:-0.003, f5:-0.003, f11:+0.002
#   CUT                    0.308  f5:-0.001, f11:+0.001, f2:+0.001
#   FINX                   0.421  f7:-0.002, f5:+0.001, f2:+0.001
#   FIW                    0.626  f6:+0.001, f5:-0.001, f1:+0.001
#   HACK                   0.233  f12:+0.002, f7:-0.001, f13:+0.001
#   ICLN                   0.242  f5:-0.002, f13:+0.002, f11:+0.001
#   IFRA                   0.663  f9:-0.001, f2:-0.001, f5:-0.001
#   IGPT                   0.174  f13:+0.001, f9:+0.001, f11:+0.001
#   IGV                    0.530  f7:-0.002, f13:+0.001, f12:+0.001
#   IPAY                   0.503  f5:+0.002, f7:-0.001, f6:+0.001
#   IRBO                   0.415  f3:+0.001, f13:+0.001, f2:+0.001
#   ITA                    0.480  f6:+0.002, f11:-0.001, f7:+0.001
#   IUSG                   0.462  f7:-0.000, f4:-0.000, f3:+0.000
#   KRE                    0.668  f8:+0.002, f10:-0.002, f5:+0.001
#   LIT                    0.199  f5:-0.003, f12:-0.002, f13:+0.001
#   MOO                    0.381  f5:-0.001, f4:+0.001, f14:+0.001
#   MTUM                   0.086  f11:+0.000, f6:+0.000, f3:+0.000
#   PAVE                   0.723  f6:+0.002, f9:-0.001, f5:-0.001
#   PBJ                    0.556  f14:+0.001, f12:+0.001, f2:-0.001
#   PBW                    0.202  f5:-0.003, f6:-0.002, f2:+0.001
#   PHO                    0.650  f6:+0.001, f5:-0.001, f1:+0.001
#   PPA                    0.481  f6:+0.001, f11:-0.001, f7:+0.001
#   QCLN                   0.240  f5:-0.003, f6:-0.001, f3:+0.001
#   QTUM                   0.467  f3:+0.001, f5:-0.001, f12:+0.001
#   QUAL                   0.294  f6:+0.000, f15:-0.000, f9:+0.000
#   ROBO                   0.544  f5:-0.002, f13:+0.001, f2:+0.001
#   SOXX                   0.806  f5:-0.003, f12:+0.002, f9:+0.002
#   SPGP                   0.271  f6:+0.001, f10:-0.001, f9:+0.000
#   URA                    0.180  f9:-0.003, f5:-0.002, f12:-0.002
#   VEGI                   0.333  f5:-0.001, f4:+0.001, f14:+0.001
#   VLUE                   0.356  f7:+0.001, f5:-0.001, f9:+0.001
#   VTV                    0.788  f1:+0.000, f7:+0.000, f6:+0.000
#   VUG                    0.660  f7:-0.000, f4:-0.000, f3:+0.000
#   WOOD                   0.235  f5:-0.002, f11:+0.001, f2:+0.001
#   XAR                    0.359  f6:+0.001, f3:+0.001, f11:-0.001
#   XBI                    0.438  f9:+0.003, f10:-0.002, f7:+0.001
#   XLE                    0.864  f4:+0.004, f3:+0.002, f14:+0.002
#   XLF                    0.697  f5:+0.001, f6:+0.001, f10:-0.001
#   XLK                    0.634  f4:-0.001, f11:-0.001, f12:+0.001
#
# building theme fingerprints:
#   Robotics & AI: 3 ETFs, avg R²=0.433, purity=0.835
#   AI Infrastructure: 3 ETFs, avg R²=0.482, purity=0.723
#   Clean Energy: 3 ETFs, avg R²=0.228, purity=0.883
#   Cybersecurity: 2 ETFs, avg R²=0.263, purity=0.999
#   Defense: 3 ETFs, avg R²=0.440, purity=0.938
#   Fintech: 3 ETFs, avg R²=0.421, purity=0.730
#   US Infrastructure: 2 ETFs, avg R²=0.693, purity=0.878
#   Agribusiness: 3 ETFs, avg R²=0.423, purity=0.822
#   Critical Minerals: 3 ETFs, avg R²=0.237, purity=0.908
#   Water: 3 ETFs, avg R²=0.621, purity=0.901
#   Timber & Forestry: 2 ETFs, avg R²=0.271, purity=0.997
#
# V2 scores (synthetic-factor-return correlation): 811 stocks x 11 themes
#   range: [-0.396, 0.412]
#
# candidate-level null test (top_30 mean score vs. 1000 random draws):
#             theme  actual_top_n_mean_score  null_p50  null_p95  null_p99  percentile_of_actual
#     Robotics & AI                   0.1857    0.0060    0.0284    0.0377                 100.0
# AI Infrastructure                   0.1707   -0.0051    0.0157    0.0264                 100.0
#      Clean Energy                   0.1845   -0.0043    0.0221    0.0322                 100.0
#     Cybersecurity                   0.1769    0.0052    0.0255    0.0344                 100.0
#           Defense                   0.2213   -0.0004    0.0272    0.0367                 100.0
#           Fintech                   0.2127    0.0126    0.0392    0.0503                 100.0
# US Infrastructure                   0.1513   -0.0210    0.0034    0.0143                 100.0
#      Agribusiness                   0.2140   -0.0178    0.0115    0.0246                 100.0
# Critical Minerals                   0.1665   -0.0141    0.0136    0.0242                 100.0
#             Water                   0.2428    0.0062    0.0341    0.0451                 100.0
# Timber & Forestry                   0.1946   -0.0115    0.0193    0.0280                 100.0
#   percentile_of_actual near 100 = clearly beats chance
#   percentile_of_actual well below 99 = cannot rule out noise for this theme

# %% [markdown]
# ### Commit to Git

# %%
# %cd "C:\\Users\\aamin\\ThemeCloner2"

# !git add .
# !git commit -m "walk-forward V2 run"
# !git push origin master
# Out:
# C:\Users\aamin\ThemeCloner2
# warning: in the working copy of '.ipynb_checkpoints/ThemeCloner_V2_WalkForward-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'ThemeCloner_V2_WalkForward.ipynb', LF will be replaced by CRLF the next time Git touches it
# [master a1687e4] walk-forward V2 run
#  2 files changed, 5714 insertions(+), 39 deletions(-)
# To https://github.com/AA-mini/ThemeCloner2.git
#    4ca2ac6..a1687e4  master -> master
